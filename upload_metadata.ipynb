# %%
FILENAME = 'meta_Electronics.json.gz'

# %%
import gzip

def get_metadata_lines():
    with gzip.open(FILENAME, 'r') as f:
        for line in f:
            yield eval(line)

# %%
next(get_metadata_lines())
# Out:
# {'asin': '0132793040',
#  'categories': [['Electronics',
#    'Computers & Accessories',
#    'Cables & Accessories',
#    'Monitor Accessories']],
#  'description': 'The Kelby Training DVD Mastering Blend Modes in Adobe Photoshop CS5 with Corey Barker is a useful tool for becoming familiar with the use of blend modes in Adobe Photoshop. For those who are serious about mastering all that Photoshop has to offer, mastering blend modes is just as important as mastering layers.In this DVD tutorial, seasoned expert Corey Barker explores the function of blend modes in a variety of scenarios such as image restoration, sharpening, adjustments, special effects and much more. Since every project scenario is different, Corey encourages you to experiment with these blend modes by giving you the skills and confidence you need.',
#  'imUrl': 'http://ecx.images-amazon.com/images/I/31JIPhp%2BGIL.jpg',
#  'title': 'Kelby Training DVD: Mastering Blend Modes in Adobe Photoshop CS5 By Corey Barker'}

# %%
ASINS = [
    'B0074BW614',
    'B00DR0PDNE',
    'B007WTAJTO',
    'B0019EHU8G',
    'B006GWO5WK',
    'B003ELYQGG',
    'B003ES5ZUU',
    'B007R5YDYA',
    'B00622AG6S',
    'B0002L5R78',
]

# %%
import gzip
def get_metadata_lines_subset(asins):
    count = 0
    with gzip.open(FILENAME, 'r') as f:
        for line in f:
            count += 1
            if count % 200 == 0: print(count)
            for asin in ASINS:
                if asin in line:
                    yield eval(line)

# %%
lines = get_metadata_lines_subset(ASINS)
asin_metadatas = []

# %%
asin_metadatas += list(lines)
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13600
# 13800
# 14000
# 14200
# 14400
# 14600
# 14800
# 15000
# 15200
# 15400
# 15600
# 15800
# 16000
# 16200
# 16400
# 16600
# 16800
# 17000
# 17200
# 17400
# 17600
# 17800
# 18000
# 18200
# 18400
# 18600
# 18800
# 19000
# 19200
# 19400
# 19600
# 19800
# 20000
# 20200
# 20400
# 20600
# 20800
# 21000
# 21200
# 21400
# 21600
# 21800
# 22000
# 22200
# 22400
# 22600
# 22800
# 23000
# 23200
# 23400
# 23600
# 23800
# 24000
# 24200
# 24400
# 24600
# 24800
# 25000
# 25200
# 25400
# 25600
# 25800
# 26000
# 26200
# ...

# %%
len(asin_metadatas)
# Out:
# 8078

# %%
subset_asin_metadatas = [x for x in asin_metadatas if x['asin'] in ASINS]

# %%
len(subset_asin_metadatas)
# Out:
# 12

# %%
len(ASINS)
# Out:
# 10

# %%
d = {x['asin']: x for x in subset_asin_metadatas}

# %%
d
# Out:
# {'B0002L5R78': {'asin': 'B0002L5R78',
#   'brand': 'DVI Gear',
#   'categories': [['Electronics',
#     'Accessories & Supplies',
#     'Audio & Video Accessories',
#     'Cables & Interconnects',
#     'Video Cables',
#     'HDMI Cables']],
#   'description': '',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41pGdJEbpTL._SY300_.jpg',
#   'price': 2.8,
#   'salesRank': {},
#   'title': 'DVI Gear HDMI Cable 2M 6 feet'},
#  'B0019EHU8G': {'asin': 'B0019EHU8G',
#   'brand': 'Mediabridge',
#   'categories': [['Electronics',
#     'Accessories & Supplies',
#     'Audio & Video Accessories',
#     'Cables & Interconnects',
#     'Video Cables',
#     'HDMI Cables']],
# ...

# %%
import json
import copy
import gzip
f = gzip.open('asin_subset_metadata.txt.gzip', 'wb')
for l in d.values():
    x = copy.deepcopy(l)
    f.write(repr(l))
    f.write('\n')
f.close()

# %%
def get_metadata_lines(fn, limit=5):
    count = 0
    with gzip.open(fn, 'r') as f:
        for line in f:
#             print line
#             count += 1
#             if count > limit:
#                 return
            yield eval(line)
            
list(get_metadata_lines('asin_subset_metadata.txt.gzip'))
# list(get_metadata_lines('meta_Electronics.json.gz'))
# Out:
# [{'asin': 'B007WTAJTO',
#   'brand': 'SanDisk',
#   'categories': [['Electronics',
#     'Computers & Accessories',
#     'Cables & Accessories',
#     'Memory Cards',
#     'Micro SD Cards']],
#   'description': "Perfect for today's high-performance Android smartphone and tablet users who want to get the most out of memory-intensive activities like 3-D gaming and apps, the SanDisk Mobile Ultra microSDHC UHS-I card drives transfer speeds of up to 30MB/s for faster app response times. For shooting Full HD video and high-megapixel pictures, it delivers two times the speed of typical microSD memory cards and a class 10 rating for the highest video recording performance available. In addition, the included SanDisk Memory Zone app lets you easily view, access, and backup all of your digital files from your phone's memory, additional memory card and cloud services all in one convenient place.",
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41yxIXed-FL._SX300_.jpg',
# ...

# %%
import pickle

with open('../product_clusters.pkl', 'r') as f:
    cluster_data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-8faea0a8793a> in <module>()
#       2
#       3 with open('../product_clusters.pkl', 'r') as f:
# ----> 4     cluster_data = pickle.load(f)
#
# /usr/local/Cellar/python/2.7.14/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pickle.pyc in load(file)
#    1382
#    1383 def load(file):
# -> 1384     return Unpickler(file).load()
#    1385
#    1386 def loads(str):
#
# /usr/local/Cellar/python/2.7.14/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
#     866             return stopinst.value
#
# /usr/local/Cellar/python/2.7.14/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pickle.pyc in load_proto(self)
# ...
