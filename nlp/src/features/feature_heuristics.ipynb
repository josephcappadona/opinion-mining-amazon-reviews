# %%
import pickle
import pprint

#product_dict: asin -> list(phrase, [adjs]), count
pp = pprint.PrettyPrinter(width=110, compact=True)
# with open("./results/features.pickle", "rb") as file:
with open("../../bad_products_features.pickle", "rb") as file:
    product_dict = pickle.load(file)

sorted_products = sorted(product_dict.items(), key=(lambda x: x[1][1]), reverse=True)
pp.pprint(sorted_products[:20])
# Out:
# [('B000CS1TLE',
#   ([('software',
#      ['willing', 'prompted', 'online', 'basic', 'has', 'have', 'starts', 'capable', 'bit', 'performs', 'easy',
#       'accompanying', 'pain', 'buggy', 'latest', 'guide', 'set', 'poor', 'work', 'latest', 'recognized',
#       'worked', 'improved', 'buggy', 'remote', 'clunky', 'wants']),
#     ('thing',
#      ['great', 'taken', 'DOA', 'next', 'is', 'good', 'need', 'whole', 'sliver', 'only', 'whole', 'only',
#       'First', 'is', 'easy', 'worked', 'only', 'is', 'no', 'make', 'bad', 'make', 'only']),
#     ('setup',
#      ['took', 'remote', 'easy', 'take', 'online', 'consume', 'audio', 'visual', 'based', 'Online', 'easy',
#       'online', 'benefit', 'friendly', 'guided', 'breeze', 'involves', 'complicated', 'adequate', 'initial',
#       'allows', 'initial', 'initial', 'failed', 'initial']),
#     ('time',
#      ['front', 'considerable', 'next', 'is', 'next', 'remote', 'more', 'hard', 'more', 'more', 'related',
#       'look', 'remote', 'remote', 'prime', 'much']),
#     ('Harmony',
#      ['identical', 'worth', 'learn', 'does', 'uses', 'solution', 'needs', 'answer', 'had', 'product', 'does',
#       'better', 'trusty', 'remote', 'is', 'old', 'got', 'has', 'has', 'non', 'functional']),
#     ('problem',
#      ['Next', 'is', 'is', 'button', 'biggest', 'disappear', 'biggest', 'was', 'typical', 'common', 'make',
#       'risen', 'major', 'exact', 'occurred', 'due', 'known', 'is', 'only', 'is']),
#     ('device',
#      ['functioning', 'inexpensive', 'defective', 'great', 'pricey', 'database', 'obscure', 'in', 'in',
#       'improvement', 'ok', 'given', 'such', 'do', 'specific']),
#     ('product',
#      ['require', 'great', 'great', 'capable', 'defective', 'better', 'great', 'Excellent', 'easy', 'amazing',
#       'outstanding', 'fails', 'great', 'great']),
#     ('unit',
#      ['earlier', 'failed', 'old', 'cheap', 'slippery', 'bad', 'able', 'works', 'stopped', 'charging',
#       'replaced', 'stopped', 'hold', 'stopped']),
#     ('way', ['is', 'able', 'is', 'logical', 'is', 'long', 'only', 'simple', 'were', 'is', 'specific']),
#     ('screen',
#      ['old', 'thing', 'shows', 'failed', 'flat', 'lighted', 'accommodate', 'active', 'large', 'began',
#       'smallish']),
#     ('RF',
#      ['requirement', 'extended', 'remote', 'remote', 'transmit', 'capable', 'remote', 'half', 'infrared',
#       'work', 'remote']),
#     ('battery',
#      ['lasts', 'healthy', 'original', 'provides', 'original', 'defective', 'rechargeable', 'bulging',
#       'rechargeable', 'bad', 'needs']),
#     ('everything', ['went', 'turns', 'ok', 'working', 'went', 'easier', 'look', 'set', 'set']),
#     ('firmware',
#      ['online', 'update', 'latest', 'update', 'upgraded', 'current', 'update', 'obligatory', 'update']),
#     ('wife', ['has', 'loves', 'thinks', 'junkie', 'able', 'loves', 'complained']),
#     ('process', ['goes', 'overall', 'set', 'entire', 'install', 'went', 'update', 'difficult']),
#     ('button', ['remote', 'global', 'is', 'used', 'different', 'have', 'does', 'sets', 'related', 'next']),
#     ('use', ['daily', 'heavy', 'early', 'constant', 'personal', 'heavy', 'normal', 'little']),
#     ('complaint',
#      ['general', 'is', 'only', 'is', 'biggest', 'is', 'is', 'only', 'is', 'main', 'secondary', 'is']),
#     ('support', ['is', 'only', 'great', 'good', 'TERRIBLE', 'technical', 'inadequate']),
#     ('hardware', ['cheap', 'unsightly', 'individual', 'ok', 'nice', 'unreliable']),
#     ('system', ['charging', 'complicated', 'pleasurable', 'complex', 'good']),
#     ('documentation', ['lousy', 'poor', 'insightful', 'included', 'useless', 'supporting']),
#     ('cradle', ['charging', 'charging', 'persnickety', 'recharging', 'recharging']),
#     ('model', ['low', 'different', 'old', 'handheld', 'good']),
#     ('harmony', ['remote', 'remote', 'works', 'works', 'take']),
#     ('computer', ['average', 'experienced', 'was', 'main', 'backup', 'main', 'work', 'savy', 'professional']),
#     ('configuration',
#      ['accurate', 'existing', 'old', 'accurate', 'good', 'seemed', 'perfect', 'corrupted', 'existing']),
#     ('equipment', ['visible', 'more', 'room', 'newer', 'electronic', 'following', 'closet']),
#     ('charge', ['wont', 'remote', 'discharged', 'several', 'full', 'full', 'go']),
#     ('issue', ['channel', 'ridiculous', 'charging', 'went', 'key', 'is', 'is']),
#     ('price', ['best', 'worth', 'added', 'outstanding', 'lowest', 'possible', 'additional']),
#     ('reason', ['only', 'was', 'clear', 'runaway', 'only', 'is', 'thanks']),
#     ('money', ['much', 'much', 'Wasted', 'hard', 'earned']), ('TV', ['different', 'mounted', 'turn', 'ON']),
#     ('bit', ['good', 'expensive', 'tried', 'is']), ('amount', ['fair', 'love', 'fair', 'extreme', 'huge']),
#     ('room', ['dark', 'remote', 'access', 'seperate']),
#     ('charger', ['have', 'work', 'sure', 'bad', 'bad', 'arriving']),
#     ('nothing', ['remote', 'worked', 'seemed', 'was', 'serious']),
#     ('cable', ['included', 'USB', 'digital', 'included', 'USB']),
#     ('receiver', ['changes', 'sits', 'remote', 'has']),
#     ('part', ['better', 'lower', 'most', 'worst', 'is', 'most']),
#     ('company', ['great', 'stands', 'great', 'smart', 'try', 'fine']),
#     ('display', ['nice', 'remote', 'conked', 'was', 'shows', 'nice']),
#     ('control', ['working', 'full', 'took', 'remote', 'overpriced', 'remote']),
#     ('option', ['only', 'was', 'useful', 'named', 'is']), ('connection', ['solid', 'fast', 'USB', 'good']),
#     ('extender', ['works', 'remote', 'remote']), ('response', ['prompt', 'good', 'quick']),
#     ('year', ['last', 'tiny', 'old']), ('one', ['okay', 'has', 'take']),
#     ('station', ['charging', 'charging', 'recharging', 'makes', 'charging']),
#     ('cabinet', ['closed', 'remote', 'ventilated']), ('idea', ['great', 'good', 'good', 'gone']),
#     ('Setup', ['consuming', 'easy', 'lengthy']), ('call', ['important', 'took', 'gave']),
#     ('RF feature', ['useful', 'fantastic', 'works']), ('life', ['working', 'become', 'super', 'long']),
#     ('Harmony software', ['latest', 'update', 'familiar']),
#     ('programming', ['existing', 'proper', 'Initial', 'confuse']),
#     ('item', ['upsetting', 'awesome', 'disposable']),
#     ('experience', ['Incredible', 'excellent', 'different', 'considerable', 'owned']),
#     ('piece', ['amazing', 'worst', 'am']), ('customer service', ['friendly', 'useful', 'amazing', 'abysmal']),
#     ('something', ['defective', 'way', 'wrong']), ('base', ['charging', 'charging', 'charging', 'charging']),
#     ('activity', ['progress', 'given', 'proper']), ('value', ['great', 'extender', 'better']),
#     ('review', ['complete', 'negative', 'past', 'separate']), ('back', ['remote', 'remote', 'few']),
#     ('RF receiver', ['capability', 'relays', 'included']),
#     ('tech support', ['seems', 'instances', 'worst', 'AWFUL']), ('buy', ['best', 'good', 'good']),
#     ('deal', ['good', 'great', 'big']), ('side', ['bottom', 'down', 'good']),
#     ('RF signal', ['make', 'makes']), ('set-up', ['quick', 'problematic']), ('user', ['use', 'know']),
#     ('LCD screen', ['stopped', 'Good']), ('contact', ['full', 'good']), ('page', ['next', 'much']),
#     ('quality', ['beta', 'build', 'poor']), ('downside', ['is', 'major', 'fact']),
#     ('day', ['blond', 'going']), ('test', ['remote', 'driving', 'drive']),
#     ('home theater', ['ready', 'different']), ('entertainment center', ['low', 'customized']),
#     ('Logitech support', ['good', 'some']), ('key', ['is', 'single', 'remote']),
#     ('hour', ['half', 'half', 'wasted']), ('contrast', ['enough', 'crisp']), ('signal', ['mixed', 'turned']),
#     ('Set-up', ['easier', 'painless']), ('performance', ['sluggish', 'best', 'best', 'best']),
#     ('CD', ['enclosed', 'enclosed', 'wayyyyyyyyyyyy']), ('couple', ['starting', 'last']),
#     ('delay', ['additional', 'is', 'gets', 'noticeable']), ('failure', ['common', 'connection']),
#     ('trick', ['is', 'troubleshooting']), ('drawback', ['only', 'biggest', 'is']),
#     ('Everything', ['there', 'runs']), ('brand', ['database', 'remote']), ('anyone', ['run', 'pay']),
#     ('message', ['recorded', 'work']), ('defect', ['occasional', 'apparent']),
#     ('command', ['learned', 'learned', 'work', 'last']), ('version', ['working', 'latest']),
#     ('machine', ['main', 'running', 'old']), ('criticism', ['only', 'be', 'biggest', 'is']),
#     ('direction', ['particular', 'remote', 'particular']), ('number', ['total', 'one']),
#     ('improvement', ['vast', 'huge']), ('Customer support', ['free', 'poor']),
#     ('step', ['unnecessary', 'additional']), ('theater system', ['complex', 'complex']),
#     ('PC', ['touchy', 'older']), ('AV system', ['complicated', 'easier', 'complex']),
#     ('camera', ['digital', 'see', 'digital']), ('return policy', ['excellent', 'excellent']),
#     ('Anyone', ['able', 'program']), ('help', ['direct', 'excellent', 'good', 'fast']),
#     ('input', ['appropriate', 'optimal']), ('.2', ['tall', 'refined']), ('advice', ['excellent', 'is']),
#     ('design', ['miserable', 'pragmatic', 'poor', 'physical', 'physical']), ('someone', ['call', 'pick']),
#     ('wait', ['minute', 'additional', 'minute']), ('button press', ['single', 'turns']),
#     ('touch', ['simple', 'nice']), ('line', ['devicesBottom', 'bottom']), ('purchase', ['client', 'worth']),
#     ('luck', ['better', 'better']), ('rating', ['highest']), ('end installer', ['high', 'charge']),
#     ('support rep', ['explain']), ('bonus', ['added']), ('electronics item', ['returned', 'go']),
#     ('RC', ['hang']), ('Resolution', ['more']), ('application', ['works']), ('touchscreen', ['remote']),
#     ('music', ['classical', 'classical']), ('Support', ['help']), ('audio signal', ['selected']),
#     ('phone', ['cordless']), ('rep', ['picked']), ('DO', ['use']), ('Learning mode', ['standard']),
#     ('actionsMinus', ['several']), ('Plus', ['helps']), ('online database', ['had']),
#     ('RF standard', ['different']), ('server command', ['last', 'is']), ('doorstop', ['dead']),
#     ('range', ['broad']), ('Chocolate Lab', ['pick']), ('equipment database', ['massive']),
#     ('Charge meter', ['shows']), ('vision', ['good', 'close']), ('reason?I', ['good']),
#     ('Logitech software', ['has']), ('navigation', ['controls']), ('TIME', ['YOUR']),
#     ('one.Support', ['old']), ('magazine', ['online']), ('RF portion', ['work']),
#     ('implementation', ['lacking']), ('model.I', ['capable']), ('capital', ['additional']),
#     ('Amazon price', ['less']), ('rocker button', ['work']), ('living room', ['small']),
#     ('Harmony concept', ['great']), ('noone', ['run']), ('years.THE BADHarmony', ['several']),
#     ('paint', ['silver', 'flaking']), ('caveat', ['is']), ('daughter', ['year', 'old']),
#     ('account', ['existing']), ('nightmare', ['total']), ('snap', ['complaint']), ('array', ['endless']),
#     ('customer service.All', ['online']), ('capability', ['great']), ('definition', ['what']),
#     ('cable box/DVR', ['central']), ('form', ['line']), ('doors.While', ['closed']), ('configure', ['work']),
#     ('Harmony line', ['remote']), ('weight', ['necessary']), ('bug', ['known']),
#     ('overhaul.I', ['complete', 'read']), ('IR extender', ['works']), ('complexity', ['perceived']),
#     ('software usability', ['poor']), ('Panasonic projector', ['front']), ('THe idea', ['whole', 'is']),
#     ('_________________________', ['admit']), ('posture', ['perfect']), ('world experience', ['real']),
#     ('batch', ['bad']), ('support center', ['excellent']), ('adventure', ['latest']),
#     ('through.The', ['included']), ('level tech', ['arranged']), ('home setup', ['average']),
#     ('them.The software', ['sucks']), ('arrangement', ['key', 'optimal']), ('impact resistance', ['better']),
#     ('Boy', ['did']), ('tastes.On top', ['personal']), ('credit', ['full']),
#     ('tweaking example', ['subtitles']), ('approach', ['alternative', 'is']), ('box product', ['open']),
#     ('object', ['additional']), ('room TV', ['main']), ('friend', ['best']), ('deal.My', ['big', 'gripe']),
#     ('feel', ['real', 'cheap']), ('raster', ['jumbled']), ('POC', ['EXPENSIVE']), ('computer savy', ['seem']),
#     ('pause', ['longer']), ('programming Harmony.I', ['deficient', 'think']),
#     ('web approach', ['included', 'alternative']), ('work.In', ['much']), ('heck ?!!', ['What']),
#     ('etc.', ['rewind']), ('limit', ['is']), ('attempt', ['more']), ('input source', ['correct']),
#     ('aLogitech Harmony', ['remote']), ('lack', ['idiot']), ('replacement', ['lasted']),
#     ('firmware2', ['latest']), ('bucks.You', ['turn']), ('world work', ['real']), ('!!!', ['remote']),
#     ('mother-in-law', ['operate']), ('Pretty procedure', ['easy']), ('anything', ['worth']),
#     ('signal method', ['set', 'spoiled']), ('response time', ['slow']), ('matter', ['SLOWWW']),
#     ('firmware upgrade.All-in-all', ['future']), ('RF alternative', ['good']), ('button push', ['single']),
#     ('information', ['much', 'useful']), ('Vista support', ['clear']), ('battery indicator', ['red']),
#     ('DVD player', ['cheap']), ('block', ['fall', 'bottom']), ('tweaking', ['took']),
#     ('button layout', ['better']), ('macro functionality', ['true']), ('Customer service', ['provided']),
#     ('IR repeater', ['flaky']), ('factory battery', ['swelled']), ('base charger', ['make']),
#     ('shelf', ['bottom']), ('manner', ['complex']), ('fix', ['devices']), ('color screen', ['commands']),
#     ('A/V', ['original', 'remote']), ('tooth capability', ['blue']), ('button lag', ['gotten']),
#     ('deletion task', ['easy', 'simple']), ('tv unit', ['direct']), ('button configuration', ['behave']),
#     ('RF/IR device', ['separate']), ('port', ['USB']), ('pad', ['Lighted', 'key']), ('setup UI', ['bear']),
#     ('zen state', ['makes']), ('story', ['Long', 'short']), ('IR', ['actual']), ('action.After', ['remote']),
#     ('customer support', ['excellent']), ('programed.It', ['remote', 'does']), ('cabinet door', ['open']),
#     ('volume control', ['works']), ('output', ['infrared', 'stopped']), ('work', ['remote']),
#     ('PC savy', ['pretty']), ('book', ['ends']), ('attitude', ['such', 'flippant']),
#     ('activities.The charger', ['works']), ('learning', ['little']), ('head', ['lot']),
#     ('Open/Close', ['was']), ('combo', ['endless']), ('solution', ['partial', 'is', 'best']),
#     ('drain', ['actual']), ('Harmony user', ['experienced']), ('logitech website', ['has']),
#     ('Logitech database', ['seems']), ('Configuration', ['takes']), ('logitech', ['control']),
#     ('A/V receiver', ['commands']), ('hold', ['long']), ('Plasma TV.I', ['older']), ('plus', ['huge']),
#     ('father', ['wanted']), ('controls.There', ['multiple', 'remote']), ('Button layout', ['located']),
#     ('carpet', ['soft']), ('Battery cover', ['broke']), ('components Receiver', ['following']),
#     ('Cool.The mode', ['main', 'is']), ('oval', ['top']), ('button block', ['lower']),
#     ('functionality', ['full']), ('glass door', ['open']), ('content', ['actual', 'adjust']),
#     ('settings library', ['excellent']), ('transaction', ['Outstanding']), ('profile', ['smart']),
#     ('IR beam', ['narrow']), ('wayyyyyyyyyyyy', ['travesty']),
#     ('customer', ['used', 'found', 'dropped', 'was']), ('style', ['personal']), ('setting', ['simple', 'is']),
#     ('connector', ['USB']), ('A manual', ['written']),
#     ('package', ['whole', 'remote', 'whole', 'complete', 'remote']), ('CD player', ['attached']),
#     ('beta', ['late']), ('month', ['about']), ('component', ['specific']),
#     ('usb cable', ['included', 'connected']), ('advantage', ['have']), ('customer experience', ['shady']),
#     ('job', ['fine']), ('support staff', ['mysterious']), ('lot/all', ['seem']), ('nit', ['minor']),
#     ('well.On side', ['plus']), ('tinkering', ['much']), ('DVDO unit', ['work', 'important']),
#     ('event', ['unlikely']), ('lockup', ['occasional']), ('IR control', ['existing', 'remote']),
#     ('wave support', ['limited']), ('integration', ['seamless']), ('HDTV', ['mounted']),
#     ('position', ['off']), ('none', ['operate']), ('Philips TSU7000', ['remote']),
#     ('sticker', ['sticker', 'wrong']), ('time.Also', ['touch']), ('person', ['admitted']),
#     ('wall', ['mounted']), ('correctly.The portion', ['set', 'came']), ('results.Support', ['great']),
#     ('suggestion', ['is']), ('benefit', ['additional']), ('simpler.On', ['little']),
#     ('IR blaster', ['works']), ('code library', ['single']), ('research', ['further']),
#     ('penny.You', ['know']), ('PS3 interface', ['blue', 'remote']), ('pronto neo', ['stood']),
#     ('layout', ['great']), ('half', ['bottom']), ('RF extender', ['handy']),
#     ('tooth', ['blue', 'blue', 'blue']), ('control design', ['intelligent', 'remote']),
#     ('activity.I', ['particular']), ('while', ['little']), ('laptop', ['comes']), ('window', ['resizeable']),
#     ('TV guide', ['onscreen']), ('time investment', ['large', 'is']), ('penny', ['pretty']),
#     ('support forum', ['loyal']), ('cat', ['thought']), ('event.HINT', ['infrequent']),
#     ('fiance', ['lost', 'use']), ('rf extender', ['remote', 'use']), ('mode', ['Learn']),
#     ('touch screen', ['remote']), ('overall.The display', ['reliable']), ('surface', ['contour', 'makes']),
#     ('price tag', ['hefty']), ('battery door', ['stay']), ('None', ['anything']),
#     ('explanation', ['written', 'useful']), ('right .2', ['basic']), ('again.Haven t', ['tried']),
#     ('orientation', ['brief']), ('knowledge', ['rudimentary']), ('basis', ['daily']),
#     ('useless.I', ['remote', 'had']), ('channel', ['specific']), ('tweeking', ['minor']),
#     ('can', ['remote', 'anything']), ('Response', ['superb']), ('programming process', ['bombed']),
#     ('good-where', ['start']), ('week.The', ['responsive']), ('Reason', ['Wonderful', 'enough']),
#     ('ease', ['seamless']), ('data base', ['has']), ('room tv', ['regular']), ('change', ['minor', 'easy']),
#     ('lcd display', ['included', 'makes']), ('flexibility', ['much']),
#     ('service experience', ['negative', 'single', 'best']), ('wee bit', ['dim']),
#     ('RF function', ['controlling']), ('DVD default', ['Eject']), ('wand', ['magic', 'magic']),
#     ('docking station', ['pain']), ('backlight', ['turns']), ('stereo system', ['old']), ('AV guy', ['set']),
#     ('silver button.Follow-up', ['top']), ('code', ['malicious']), ('top box', ['arcane']),
#     ('volume', ['skinny', 'enough']), ('box item', ['open']), ('computer setup', ['Initial', 'simple']),
#     ('function', ['is']), ('concept', ['good']), ('area', ['larger']), ('custom', ['programmed']),
#     ('tech service', ['lame']), ('RF/IR base', ['remote']), ('discussion thread', ['provided']),
#     ('screen.Nope', ['blue']), ('resolution', ['great']), ('info', ['hard']),
#     ('client software', ['lose', 'has']), ('bump', ['little', 'knocks']), ('tv hd', ['direct', 'sat']),
#     ('offer', ['refurbished']), ('motion', ['lights']), ('down-side', ['arrangement']), ('method', ['tried']),
#     ('cover', ['holds']), ('I wrong!I', ['have']), ('operation', ['difficult']), ('AppleTV', ['controlled']),
#     ('time.It', ['doing']), ('McDonalds meal', ['happy']), ('guy', ['get']), ('lot', ['doors']),
#     ('game', ['features']), ('lighting', ['problematic']), ('scripting', ['key']),
#     ('interface', ['web', 'USB']), ('battery life', ['excellent']), ('usability', ['excellent']),
#     ('girl', ['old']), ('press', ['feels']), ('Device mode', ['allow']), ('change channel', ['fast']),
#     ('s/w', ['initial', 'install']), ('learning exercise', ['remote']), ('glitch', ['caused']),
#     ('picture', ['flat']), ('commands.Bottom-line', ['various']), ('DVD', ['hidden']),
#     ('Bottom line', ['configure']), ('RF-IR repeater', ['included']), ('running', ['remote']),
#     ('cause', ['remote']), ('place', ['better']), ('couch potato', ['easier']),
#     ('light', ['back', 'weak', 'Blue', 'shows']), ('problems.This', ['little', 'remotes', 'remote']),
#     ('videophile', ['have']), ('switching process.It', ['lengthy']), ('ease user', ['real']),
#     ('cradle issue', ['better']), ('IR noise', ['severe']), ('wish', ['biggest', 'is']),
#     ('everyone', ['use']), ('Word', ['converts']), ('pizza', ['good']), ('wizard', ['limiting']),
#     ('activies button', ['different']), ('support operator', ['initial', 'refused']),
#     ('to.Well', ['disappointed']), ('eyesight', ['great']), ('Wife', ['love']),
#     ('end shop', ['expensive', 'high']), ('night recording', ['late']), ('inconvenience', ['minor']),
#     ('touch pad.I', ['entire', 'control']), ('Nokia BLB-2', ['works']), ('Remote user', ['satisfied']),
#     ('IR/RF capability', ['is']), ('Button placement', ['better']), ('background', ['blue']),
#     ('malfunction', ['is']), ('input everything', ['needs']), ('tab', ['broke']),
#     ('model number', ['different']), ('grail', ['holy']), ('trouble', ['able']), ('family', ['challenged']),
#     ('charger.I', ['included']), ('TV unit', ['Direct']), ('legacy', ['remote']),
#     ('support.Logitech', ['miserable']), ('substitute', ['is']), ('system setup', ['difficult']),
#     ('model Harmony', ['lower']), ('sub-woofer', ['remote', 'controlled']), ('hd mode', ['proper']),
#     ('junk', ['complete']), ('freezing', ['fixed']), ('troubleshooting guide', ['online']),
#     ('mess', ['cluttered']), ('feature', ['little']), ('expectation', ['reasonable']),
#     ('circuit board', ['main']), ('Mac support', ['poor']), ('circle layout', ['dual']), ('X10', ['has']),
#     ('recommendation', ['is']), ('writer', ['had']), ('patience', ['easy']), ('angle', ['wider']),
#     ('consumer devicesI', ['electronic']), ('son', ['experienced']), ('size', ['standard', 'remote']),
#     ('backlighting', ['wonderful'])],
#    135)),
#  ('B000629GES',
#   ([('quality',
#      ['high', 'poor', 'little', 'better', 'Audio', 'OK', 'good', 'decent', 'Good', 'going', 'is', 'approach',
#       'good', 'overall', 'audio', 'higher', 'Sound', 'important', 'clear', 'audio', 'average', 'good',
#       'Sound', 'good', 'amazing', 'better', 'good', 'Sound', 'good', 'nice', 'good', 'Good', 'miserable',
#       'good', 'Good', 'excellent']),
#     ('noise',
#      ['more', 'works', 'better', 'white', 'white', 'unwanted', 'unwanted', 'extraneous', 'blocking', 'let',
#       'canceling', 'white', 'environmental', 'much', 'annoying', 'white', 'feature', 'white', 'regular',
#       'white', 'many', 'canceling', 'hissing', 'white', 'unbelievable', 'came', 'works', 'white', 'perfect',
#       'cancelling', 'definite', 'white']),
#     ('sound',
#      ['quiet', 'hiss', 'went', 'unaffected', 'satisfactory', 'fine', 'audio', 'good', 'richer', 'exceptional',
#       'hissing', 'bothered', 'Overall', 'acceptable', 'slight', 'hissing', 'is', 'comparable', 'distorted',
#       'great', 'incredible', 'whining', 'good', 'recommend', 'greater', 'own', 'hissing', 'whooshing', 'loud',
#       'good']),
#     ('product',
#      ['good', 'stylish', 'uncomfortable', 'good', 'enough', 'Great', 'great', 'good', 'solid', 'Good',
#       'mechanical', 'felt', 'Good', 'rate', 'best', 'does', 'breakable']),
#     ('music',
#      ['playing', 'starts', 'quieter', 'pleasurable', 'played', 'played', 'loud', 'starts', 'starts',
#       'playing', 'is', 'becomes', 'loud']),
#     ('job',
#      ['good', 'excellent', 'excellent', 'good', 'good', 'done', 'good', 'good', 'good', 'great', 'great']),
#     ('noise canceling', ['good', 'good', 'works', 'looked', 'superb', 'features', 'works', 'do', 'decent']),
#     ('flight', ['hours', 'long', 'returning', 'noisy', 'long', 'commercial', 'peaceaful', 'long']),
#     ('bass', ['deep', 'strong', 'deep', 'more', 'overpowering', 'more', 'good', 'much', 'amazing']),
#     ('pair',
#      ['cheap', 'great', 'tight', 'fitting', 'do', 'good', 'looking', 'best', 'better', 'average', 'good']),
#     ('price', ['reasonable', 'great', 'low', 'reasonable', 'good', 'refurb', 'good']),
#     ('feature', ['canceling', 'spectacular', 'cancelling', 'enabled', 'cancel', 'works', 'canceling']),
#     ('set', ['Bose', 'feels', 'third', 'DOA', 'ought', 'bad', 'great', 'good', 'solid', 'comfortable']),
#     ('buy', ['great', 'good', 'great', 'good', 'good', 'good']),
#     ('time', ['only', 'found', 'long', 'long', 'long']),
#     ('noise cancelling', ['turned', 'MINIMAL', 'good', 'good', 'more']),
#     ('use', ['daily', 'prolonged', 'normal', 'specific', 'long', 'daily']),
#     ('pouch', ['carrying', 'nice', 'thick', 'whole', 'giant', 'nice', 'included', 'do']),
#     ('something', ['better', 'negative', 'expensive', 'wrong', 'acceptable']),
#     ('thing', ['length', 'nice', 'is', 'is', 'only', 'fact']), ('side', ['fragile', 'rough', 'work', 'plus']),
#     ('wife', ['came', 'has', 'tends', 'has']), ('battery', ['seems', 'goes', 'side', 'stays']),
#     ('bit', ['little', 'little', 'comes', 'little']),
#     ('difference', ['dramatic', 'huge', 'minimal', 'turned', 'only', 'is']),
#     ('level', ['low', 'low', 'seems', 'moderate']),
#     ('noise cancellation', ['close', 'active', 'active', 'does', 'okay']),
#     ('problem', ['only', 'is', 'ongoing', 'band', 'is']),
#     ('Bose', ['option', 'go', 'stolen', 'sorry', 'make']),
#     ('hiss', ['added', 'soothing', 'faint', 'slight', 'is', 'perceptible', 'was']),
#     ('headset', ['good', 'defective', 'great', 'works', 'decent', 'seems']),
#     ('design', ['open', 'folding', 'clean', 'simple', 'solid']), ('reason', ['odd', 'is', 'biggest']),
#     ('range', ['certain', 'entire', 'db', 'full', 'sounds', 'certain', 'certain', 'huge']),
#     ('day', ['room', 'wear', 'coming']), ('nothing', ['fancy', 'remarkable', 'wrong']),
#     ('head', ['mobile', 'large', 'small', 'super', 'small']), ('deal', ['good', 'fair', 'good', 'good']),
#     ('piece', ['little', 'was', 'separate', 'interesting']),
#     ('noise reduction', ['works', 'going', 'internal', 'cancels']), ('ear', ['entire', 'hurts', 'type']),
#     ('plastic', ['hard', 'durable', 'better', 'synthetic', 'tasteful']),
#     ('environment', ['normal', 'working', 'controlled', 'inside']),
#     ('headphone', ['good', 'refurbished', 'cheaper', 'cheaper', 'light']),
#     ('volume', ['increases', 'lower', 'full', 'high', 'harmful']),
#     ('device', ['audio', 'audio', 'cancelling', 'go']),
#     ('background noise', ['constant', 'is', 'white', 'much', 'constant']),
#     ('comfort', ['is', 'suffers', 'Overall', 'compartment', 'loud', 'ok']),
#     ('switch', ['canceling', 'is', 'accessible']), ('music listener', ['avid', 'persnickety']),
#     ('year', ['about', 'last']), ('cancellation', ['works', 'works']), ('amount', ['small', 'fair']),
#     ('frequency response', ['good', 'single', 'overall']), ('choice', ['excellent', 'fine', 'good']),
#     ('end', ['high', 'high', 'became', 'low', 'low']), ('listener', ['hears', 'casual']),
#     ('pause', ['is', 'brief', 'is']), ('replacement', ['good', 'amazing']), ('snob', ['audio', 'audio']),
#     ('pressure', ['less', 'becomes']), ('reduction', ['total', 'decibel', 'great', 'slight', 'is']),
#     ('way', ['works', 'convenient']), ('AAA battery', ['rechargeable', 'lasted', 'single']),
#     ('reviewer', ['have', 'complained']), ('circuitry', ['working', 'is']),
#     ('cancellation feature', ['cool', 'has']), ('notch', ['top', 'top']), ('model', ['better', 'exact']),
#     ('foam', ['circular', 'soft', 'rests', 'cheap']), ('material', ['scratchy', 'thin']),
#     ('computer', ['last', 'vaio', 'makes']), ('alternative', ['cheaper', 'good']),
#     ('part', ['outer', 'Bad', 'putting']), ('battery compartment', ['pressed', 'located']),
#     ('quest', ['continuing', 'ended']), ('package', ['neat', 'fragile']),
#     ('solution', ['good', 'reasonable']), ('doesnt', ['noticable', 'reduce']),
#     ('value', ['good', 'clear', 'wear']), ('cost', ['less', 'less']), ('criticism', ['is', 'major', 'is']),
#     ('money', ['much', 'more']), ('trip', ['recent', 'international', 'hour']),
#     ('lot', ['cheaper', 'provide']), ('fact', ['bonus', 'recommend']), ('week', ['last', 'next']),
#     ('ear piece', ['hard', 'failed']), ('Sound', ['coming', 'OK']), ('issue', ['only', 'is', 'only']),
#     ('Sony MDR-NC6', ['has', 'choice']), ('decrease', ['definite', 'was']), ('volume boost', ['wonderful']),
#     ('car', ['great']), ('crystal', ['clear']), ('spot', ['odd']), ('uieter', ['much', 'comfortable']),
#     ('earphone thing', ['whole']), ('plug', ['designed', 'goes']), ('advertising', ['false']),
#     ('user', ['more', 'friendly']), ('someone', ['wanting']), ('element', ['hard']),
#     ('beast.All-in-all', ['surly']), ('jet flight', ['long']), ('generation Bose', ['newest']),
#     ('use.I', ['prolonged']), ('waste', ['What']), ('mine', ['bought']), ('you.A value', ['great']),
#     ('cup style', ['cushioned']), ('Cancelling headset', ['does', 'detects']),
#     ('performance', ['superior', 'solid']), ('band', ['stiff']), ('blister pack', ['dreaded']),
#     ('matter compartment', ['touch', 'located']), ('response', ['better']), ('sender', ['paid']),
#     ('padding.The noise', ['cheap']), ('look', ['hard']), ('assumption', ['dumb']), ('evidence', ['more']),
#     ('LOT', ['is']), ('midrange', ['good']), ('cancellation function', ['works']), ('music sound', ['great']),
#     ('AAA', ['single']), ('technology', ['slick']), ('mini-plug', ['torn']), ('bonus', ['added', 'is']),
#     ('din', ['growling', 'hissing']), ('review', ['mentioned']), ('room', ['soundproofed']),
#     ('reinforcement', ['is']), ('investment', ['whole']), ('preference', ['individual']),
#     ('shift', ['definite']), ('bad.I', ['thought']), ('passive headphone.I', ['cheap', 'Japanese']),
#     ('plane.The price', ['made']), ('air flow', ['annoying']), ('test', ['ultimate']),
#     ('size head', ['average']), ('drummer', ['sitting']), ('order', ['arrive']),
#     ('equipment', ['electronic', 'working']), ('holder', ['broke']), ('reviews.These sound', ['great']),
#     ('giraffe', ['get']), ('lifespan', ['short']), ('portion', ['good']), ('lie', ['outright']),
#     ('subway', ['rumble']), ('audio channel', ['gone']), ('flight attendant', ['saying']),
#     ('duration', ['long']), ('ear pad', ['enclosing']), ('attachment', ['separate']),
#     ('noise effect', ['filtering']), ('headband.I', ['buy']), ('onthe package', ['shows']),
#     ('briefcase.I', ['decided']), ('hotel room', ['elevators']), ('parts too.Not', ['foldable']),
#     ('frequency hiss', ['higher']), ('friend', ['best', 'agreed']), ('source', ['audio']),
#     ('marriage', ['happy']), ('Vision M', ['Creative']), ('Noise feature', ['cancelling', 'best']),
#     ('price point', ['commensurate']), ('noise leakage', ['additional']), ('ER-6i', ['Etymotic']),
#     ('frequency thrumming', ['low']), ('customer service', ['fantastic']), ('ventillation system', ['makes']),
#     ('hardcore', ['try']), ('left channel', ['quit']), ('noise machine', ['white']), ('drone', ['prompted']),
#     ('Noise cancellation', ['works']), ('bummer', ['real']), ('anything', ['much']), ('skull', ['sore']),
#     ('Ca', ['wait']), ('ear coverage', ['causes']), ('C/S guy', ['care']), ('motor', ['sounds']),
#     ('DVD player', ['portable']), ('bill', ['filled']), ('location', ['quiet']), ('clip', ['safty', 'work']),
#     ('bass response', ['good']), ('portability', ['great']), ('cord length', ['long']),
#     ('hat size', ['scares']), ('complaint', ['only', 'is']), ('price point.If', ['higher']),
#     ('reduction feature', ['headphones']), ('units.One note', ['expensive']), ('audio', ['dynamic']),
#     ('shape', ['perfect']), ('chatter', ['constant']), ('fate', ['have']), ('point', ['whole']),
#     ('story', ['Long']), ('research', ['much']), ('amazon', ['sold']), ('packaging', ['original']),
#     ('volume control', ['has']), ('bass sound', ['solid']), ('price.This noise', ['standard']),
#     ('student', ['came']), ('item', ['good']), ('that.I', ['have']), ('amp', ['cancelling']),
#     ('bargain', ['absolute']), ('opinion', ['positive']),
#     ('overall.They', ['performed', 'excellent', 'eliminated']), ('power', ['electric']),
#     ('fidelity', ['superior']), ('quality product', ['higher']), ('SFO machine', ['vending']),
#     ('noise elimination', ['complete']), ('NC', ['enabled']), ('base.When', ['putting']), ('need', ['is']),
#     ('compromiseFor', ['great']), ('!!', ['good']), ('frequency noise', ['low', 'is']),
#     ('cancellation technology', ['works', 'active', 'relies']), ('wiring connection', ['bad']),
#     ('MDR-NC6', ['eliminate']), ('WoW!These', ['comfy']), ('business trip', ['recent']),
#     ('music.Also', ['loud']), ('mm jack', ['long']), ('CD player', ['portable']), ('month', ['about']),
#     ('tight/heavy', ['little']), ('Shack salesman', ['tried']), ('lol', ['enough']),
#     ('sub market', ['dollar', 'limited']), ('tick-tick', ['faint']), ('reproduction', ['great']),
#     ('center hinge', ['was']), ('distortion', ['is']), ('drawback', ['only', 'real', 'is']),
#     ('wind', ['hit']), ('one.However', ['regular']), ('SOLD IN.There', ['two']), ('relief', ['temporary']),
#     ('end pair', ['higher']), ('noise headphone', ['cancelling']), ('Everything', ['average']),
#     ('Sony NC7', ['gotten']), ('heating system', ['noisy', 'central', 'quiet']),
#     ('pocket change', ['potential', 'much']), ('Background noise', ['sounds', 'lessens']),
#     ('head piece', ['uncomfortable', 'hard', 'plastic']), ('coverage', ['actual', 'full']),
#     ('headphone.I', ['cheap', 'bit']), ('volume level.However', ['better']), ('headphones.I', ['do']),
#     ('head bar', ['plastic']), ('sound value', ['constant', 'standard', 'high']), ('cord', ['connects']),
#     ('cushion', ['fits']), ('buzz', ['constant']), ('them.My complaint', ['biggest']), ('frequency', ['low']),
#     ('plus.I', ['real']), ('size', ['smaller']), ('headband', ['pushes']), ('something duty', ['heavy']),
#     ('Bose Comfort', ['Quiet']), ('AC', ['loud', 'noise']), ('fashion', ['universal']), ('basis', ['daily']),
#     ('silence', ['complete']), ('laughingstock', ['made']), ('hour', ['about']),
#     ('phones!Great quality', ['audio']), ('free.DesignThe design', ['clean', 'contemporary']),
#     ('bet', ['good']), ('ear bud', ['give', 'closer']), ('change', ['significant', 'is']),
#     ('Sony quality', ['dipped']), ('headphone set', ['type']), ('plane', ['prop']), ('average', ['above']),
#     ('flyer', ['frequent']), ('improvement', ['is']), ('brand', ['skullcandy']), ('foam padding', ['good']),
#     ('airplain noise', ['cancelling']), ('wire design', ['single']), ('headphone jack', ['used', 'normal']),
#     ('Sony product', ['only']), ('feeling', ['uncomfortable']), ('reproduction quality', ['good']),
#     ('JetBlue flight', ['recent']), ('padding', ['came']), ('noise technology', ['canceling']),
#     ('airport', ['busy']), ('lakes', ['great']), ('price muchg', ['lower']), ('case', ['sold']),
#     ('Sennheiser', ['overall', 'offer']), ('distinct.They', ['perform']), ('Today', ['brought']),
#     ('carpet ride', ['magic']), ('room.I', ['different']), ('bag', ['nice', 'little']),
#     ('blocker', ['better']), ('ellipsoid', ['oblate']), ('clarity', ['better']), ('hissing', ['strong']),
#     ('girlfriend', ['Former', 'lost']), ('pain', ['took']), ('length.I', ['normal']), ('up.You', ['drop']),
#     ('move', ['wrong']), ('premium.But', ['small']), ('kind', ['short']), ('help', ['much']),
#     ('guess', ['is']), ('return', ['diminishing']), ('canceling mode', ['useless']),
#     ('listener cause', ['average']), ('fitThey', ['comfortable']), ('name', ['better', 'noise']),
#     ('battery life.If', ['excellent']), ('plastic holder', ['cheap']), ('tax', ['local']),
#     ('anyone', ['was']), ('decibel', ['low']), ('run.UPDATE', ['long']), ('concern', ['primary']),
#     ('.2', ['heavy']), ('warranty', ['expired']), ('gift', ['use']), ('packet', ['small']),
#     ('white-noise sound', ['distinct', 'hissing', 'is', 'reminiscent']), ('noise feature', ['canceling']),
#     ('sound feature', ['canceling']), ('treble', ['clear']), ('heating system.Unfortunately', ['forced']),
#     ('frequency range', ['effective', 'included']), ('music reproduction', ['whole']), ('budget', ['strict']),
#     ('heater', ['is']), ('purchase', ['Excellent']), ('Noise cancelling', ['works']),
#     ('option', ['cheap', 'cancelling']), ('choice.The caveat', ['superb', 'big']),
#     ('aircrew headset', ['good']), ('force', ['physical']), ('airplane headphone', ['prong']),
#     ('tape', ['blank'])],
#    129)),
#  ('B00007LTBA',
#   ([('router',
#      ['connect', 'drops', 'great', 'keep', 'cheap', 'reboots', 'failed', 'work', 'excellent', 'own', 'good',
#       'excelent', 'rebooting', 'TURKEY', 'good', 'single', 'had', 'wired', 'Linksys', 'work', 'locks', 'work',
#       'froze', 'functions', 'took', 'floor', 'worked', 'DOES', 'working', 'connect', 'hums', 'old',
#       'rebooting', 'located', 'support', 'slower', 'going', 'old', 'bag', 'reboots', 'reboots', 'works',
#       'reliable', 'good', 'end']),
#     ('firmware',
#      ['upgraded', 'single', 'Upgraded', 'late', 'load', 'future', 'support', 'introduce', 'installed',
#       'version', 'latest', 'update', 'updated', 'update', 'latest', 'latest', 'latest']),
#     ('range',
#      ['limited', 'poor', 'close', 'Great', 'easy', 'easy', 'such', 'poor', 'great', 'great', 'great', 'find',
#       'staying', 'good', 'good', 'good', 'signal', 'poor', 'excellent', 'bad', 'better']),
#     ('signal',
#      ['goes', 'GREAT', 'good', 'strong', 'excellent', 'strong', 'good', 'better', 'better', 'do', 'single',
#       'full', 'strong', 'strong', 'everywhere', 'became', 'good']),
#     ('connection',
#      ['poor', 'simple', 'good', 'drop', 'dropped', 'works', 'sustains', 'drops', 'drop', 'remote', 'instable',
#       'wired']),
#     ('setup',
#      ['simple', 'had', 'basic', 'manual', 'easy', 'easy', 'overall', 'straight', 'simple', 'easy', 'price',
#       'easy', 'additional', 'special']),
#     ('speed',
#      ['Excellent', 'fast', 'raw', 'Great', 'full', 'excelent', 'has', 'highest', 'Overall', 'fast', 'top',
#       'excellent']),
#     ('product',
#      ['great', 'appears', 'simple', 'price', 'awful', 'has', 'good', 'great', 'great', 'recommended']),
#     ('reason', ['good', 'only', 'good', 'main', 'explicable', 'is', 'only', 'apparent', 'given']),
#     ('unit', ['vintage', 'older', 'working', 'bad', 'replaced', 'reliable', 'terrible', 'gave']),
#     ('network', ['secured', 'wired', 'running', 'internal', 'entire', 'available']),
#     ('everything', ['worked', 'helped', 'worked', 'working', 'replug', 'ran']),
#     ('thing', ['Same', 'have', 'First', 'was', 'solid', 'is']),
#     ('house', ['different', 'whole', 'bigger', 'entire', 'average', 'whole', 'covered']),
#     ('DI-624', ['refurbished', 'working', 'exception', 'located', 'Router']),
#     ('performance', ['improved', 'incredible', 'Great', 'fourth', 'overall']),
#     ('tech support', ['said', 'faltering', 'about', 'help', 'difficult']),
#     ('issue', ['unit', 'resolve', 'only', 'is', 'took', 'known']),
#     ('problem', ['is', 'ridiculous', 'is', 'router', 'such', 'common']),
#     ('time', ['long', 'short', 'reviews', 'entire']),
#     ('part', ['good', 'seems', 'most', 'most', 'hardest', 'figuring']),
#     ('year', ['about', 'over', 'about', 'over']), ('device', ['take', 'require', 'horrible', 'easy']),
#     ('floor', ['different', 'top', 'third', 'top']), ('price', ['small', 'better', 'great', 'excellent']),
#     ('tech', ['experienced', 'patient', 'helpful']), ('computer', ['hooked', 'time', 'main']),
#     ('customer service', ['GREAT', 'gets', 'become']), ('support', ['be', 'SUCKS', 'technical', 'has']),
#     ('installation', ['simple', 'easy', 'snap']),
#     ('internet connection', ['present', 'appears', 'hardwired', 'useless']),
#     ('configuration', ['difficult', 'intuitive', 'better']), ('way', ['only', 'is', 'have', 'only']),
#     ('experience', ['personal', 'personal', 'mine']), ('software', ['has', 'good', 'latest']),
#     ('deal', ['cheap', 'big', 'good']), ('user', ['goes', 'experienced']), ('none', ['brings', 'necessary']),
#     ('feature', ['full', 'set', 'undocumented', 'is']), ('g', ['extreme', 'basic']),
#     ('amount', ['least', 'compelling', 'sustained']), ('review', ['helpful', 'above', 'perspective']),
#     ('documentation', ['excellent', 'is']), ('someone', ['causing', 'changed']),
#     ('DI-624 router', ['horrid', 'disconnects']), ('money', ['more', 'missing']),
#     ('improvement', ['vast', 'big']), ('idea', ['good', 'whole']), ('Setup', ['easy', 'works']),
#     ('version', ['downloadable', 'latest']), ('web interface', ['makes', 'easy']),
#     ('anything', ['serious', 'more']), ('Linksys router', ['conked', 'good', 'stable']),
#     ('information', ['important', 'required']), ('kind', ['professional', 'selling']),
#     ('workhorse', ['little', 'reliable']), ('anyone', ['has', 'interested']),
#     ('impression', ['lasting', 'is']), ('right', ['next', 'fine']), ('laptop', ['seem', 'works']),
#     ('card', ['loses', 'matching']), ('DWL-G650', ['PCCard', 'gets']),
#     ('option', ['specific', 'desired', 'sure', 'correct']), ('luck', ['bad', 'good']),
#     ('month', ['about', 'about']), ('card.When', ['receiving']), ('piece', ['discontinued']),
#     ('WPA security', ['Strong', 'breeze']), ('system', ['reliable']), ('factory reset', ['full']),
#     ('home network', ['existing', 'wired']), ('job', ['good']), ('phone line', ['interfering']),
#     ('one', ['has']), ('Dlink product', ['notorious']), ('Broadcast strength', ['strong']),
#     ('worked.What', ['blows']), ('digit code', ['key']), ('Nothing', ['helps']), ('equipment', ['work']),
#     ('network.Needless', ['local']), ('room.The device', ['next']), ('Installation', ['quick']),
#     ('FW', ['latest']), ('shame', ['What']), ('wire', ['hard']), ('printer.While set-up', ['networked']),
#     ('setup process', ['entire']), ('something', ['else']), ('Support', ['nice']), ('phone', ['cordless']),
#     ('ago.Prior', ['router']), ('page', ['admin']), ('MB', ['few']), (':--RRB-', ['normal']),
#     ('reception', ['bad']), ('cards.So', ['different']), ('effort', ['little']),
#     ('beta firmware', ['available']), ('junk leftover', ['needs']), ('password', ['admin', 'got']),
#     ('surprise', ['nice']), ('customer support', ['free', 'plus']), ('upgrade', ['last']), ('moon', ['blue']),
#     ('coverage', ['less']), ('company', ['has']), ('web site', ['Canadian']),
#     ('problems.The router', ['past']), ('rev_C', ['has']), ('extender DWL-G800AP', ['work']),
#     ('networking card', ['supports']), ('surfing experience', ['smooth']), ('brick house', ['large']),
#     ('depth.One note', ['substantial', 'final']), ('Conclusion', ['get']), ('technology', ['is']),
#     ('peoples company', ['most']), ('shelf', ['bottom']), ('networking device', ['worst']),
#     ('work', ['wont']), ('switch right', ['wired']), ('it.The problem', ['configuration']),
#     ('potential', ['full']), ('offering', ['weak']), ('file', ['saved']), ('host', ['whole']),
#     ('track record', ['awful']), ('server built-in', ['wired']), ('mode', ['applies']), ('link', ['work']),
#     ('positioning', ['careful']), ('connection wizard', ['nice', 'easy']), ('process', ['took']),
#     ('posting.Now', ['unbiased']), ('week', ['about']), ('performer', ['fast']), ('D-link router', ['old']),
#     ('control', ['broader']), ('knowledge', ['troubleshooting']), ('basis', ['regular']),
#     ('antenna', ['single']), ('I.P.', ['thank']), ('firewall', ['has']), ('hour', ['about']),
#     ('Sony Laptop', ['had']), ('flaw', ['big']), ('utility', ['own', 'see']), ('place', ['small']),
#     ('ease', ['overall', 'GREAT']), ('signal strength', ['great']), ('toolset', ['nice']),
#     ('notch performance', ['immediate', 'top']), ('building software', ['job']), ('change', ['nice']),
#     ('Set-up', ['took']), ('wife', ['getting']), ('router page', ['admin']), ('feature list', ['exhaustive']),
#     ('Mbps router', ['loses', 'old', 'slower']), ('vintage', ['older']), ('C router', ['have']),
#     ('LAN', ['fine']), ('desktop', ['remote']), ('purpose', ['original']), ('direction', ['acurate']),
#     ('batch', ['bad', 'is']), ('reset routine', ['monthly', 'raise']), ('PCI card', ['froze']),
#     ('man', ['grumpy', 'irriated']), ('setup wizard', ['DOA']), ('phone base', ['foot']),
#     ('mode.The unit', ['wired']), ('reboot', ['frequent', 'frequent']),
#     ('model router.I', ['different', 'had']), ('108mps adapter', ['matching']), ('t', ['forget']),
#     ('pcmcia card', ['matching']), ('Got ta', ['love']), ('site support', ['Excellent']),
#     ('service', ['flawless']), ('D-L', ['works']), ('DI-624c', ['work']), ('DHCP feature', ['static']),
#     ('D-Link system', ['performed']), ('setup problem', ['simple']), ('network product', ['worst']),
#     ('friend', ['set', 'came']), ('PC', ['illiterate']), ('networking gear', ['best']),
#     ('con', ['only', 'is']), ('DI-614', ['old']), ('Works fine', ['enabled']), ('release', ['recent']),
#     ('minute call', ['needed']), ('Disclosure', ['Full']), ('DLINK', ['refuses']),
#     ('transfer speed', ['full']), ('configuration interface', ['excellent']), ('nothing', ['make']),
#     ('key', ['random']), ('guy', ['front']), ('WG111 adapter', ['USB']), ('broadcasting channel', ['latest']),
#     ('switch togeher', ['general']), ('story ft', ['square']), ('exchange', ['do']), ('wep', ['enabled']),
#     ('108mbps throughput', ['full']), ('route', ['direct']), ('setup guide', ['quick', 'went']),
#     ('cover', ['know']), ('dlink card', ['compatible']), ('buffering', ['more', 'drops']),
#     ('router upstairs', ['connected']), ('bag', ['real']), ('Router', ['powerful', 'gets']),
#     ('Connection speed', ['respectable']), ('brands.There', ['major']), ('lookup problem', ['intermittent']),
#     ('firmware page', ['appear']), ('XP home', ['running']), ('answer', ['ready']), ('wireless', ['dlink']),
#     ('b router', ['replacing']), ('G', ['super']), ('revision A/B', ['has']), ('daughters laptop', ['picks']),
#     ('point', ['Whole', 'is']), ('at-home', ['small']), ('super-G card', ['get']),
#     ('connection speed', ['stable']), ('Speed', ['great']), ('mobility', ['more']),
#     ('reset', ['manual', 'did']), ('user software', ['friendly']), ('speed decrease', ['noticable']),
#     ('story', ['single']), ('margin', ['fair']), ('Customer support', ['clueless']), ('swotch', ['internal']),
#     ('didnt help', ['latest']), ('Gigafast card', ['cheap']), ('rebate', ['current']), ('guide', ['quick']),
#     ('help', ['big']), ('word', ['last']), ('home user', ['typical']), ('WPA-PSK', ['secure']),
#     ('revision A', ['defective']), ('no-no', ['big']), ('modem', ['internal']), ('website', ['informative']),
#     ('Everyone', ['says']), ('adaptor', ['USB', 'hooked']), ('WAN link', ['drop']),
#     ('support website', ['EXCELLENT']), ('Price', ['great']), ('wizard', ['guide']), ('view', ['clear']),
#     ('LinkSys router', ['requires']), ('WPA mode', ['unstable']), ('g protocol', ['more']),
#     ('WAP device', ['older']), ('day', ['filed']), ('ADSL modem', ['works']), ('toll support', ['free']),
#     ('technician', ['told']), ('trouble', ['much']), ('wish', ['retrospect']), ('well.I', ['impressed']),
#     ('vendor', ['popular']), ('backup router', ['NIGHTMARE']), ('DLink router', ['old']),
#     ('booklet', ['included']), ('PSK key', ['simple', 'generate']), ('level', ['low']),
#     ('firmware/driver', ['newest']), ('packaging', ['larger', 'smaller']), ('novice', ['able']),
#     ('pre-sales staff', ['referred']), ('SSID broadcast', ['disabled']), ('products.Anyway', ['most']),
#     ('Linksys code', ['official', 'fails']), ('encryption format', ['old']), ('switch portion', ['wired']),
#     ('printer', ['USB', 'connected']), ('firmware upgrade', ['latest']), ('DLink', ['does']),
#     ('speed.Before', ['great']), ('wifi security', ['basic']), ('resetting', ['needed', 'work']),
#     ('Ethernet card', ['regular']), ('solution', ['manual']), ('Firmware', ['support']),
#     ('Wireless connection', ['worked']), ('model', ['different']), ('PPPoE', ['disconnect']),
#     ('point/wi-fi router', ['works']), ('system.Great stuff', ['entire', 'super']), ('packet', ['single']),
#     ('try', ['dissapointing']), ('strike', ['counter']), ('PCCard', ['good']),
#     ('page.Still kinda', ['admin']), ('Everything', ['is']), ('network.Am', ['true', 'happy']),
#     ('Poor support', ['technical']), ('years.The', ['Good']), ('everthing', ['suprisingly']),
#     ('plus', ['great']), ('bit', ['little']), ('G mode', ['super']), ('di-624', ['stellar']),
#     ('situation', ['worse']), ('fine', ['connected', 'showed']), ('signal problem', ['went']),
#     ('manual', ['help']), ('success', ['great']), ('line', ['had']), ('purchase', ['good']),
#     ('respond', ['doesnt', 'happy']), ('Cisco router', ['superior']), ('lot', ['give']),
# ...
#     ('receiverThe touchscreen', ['projectorPanasonic', 'PlasmaDish', 'receiverDish', 'clear']),
#     ('conversation gadget', ['nice']), ('television', ['know']), ('PC database', ['accessible']),
#     ('computer programmer', ['professional']), ('marantz', ['has', 'remote']), ('reaction', ['been']),
#     ('advantage', ['only', 'real', 'display']), ('reboot', ['occasional']),
#     ('risk', ['unnecessary', 'accessible']), ('impression', ['was']), ('try', ['more']),
#     ('stash', ['secret']), ('Harmony had.If', ['old']), ('call', ['confirmed']), ('Part', ['me']),
#     ('PDA look', ['mean']), ('task', ['simple']), ('activity setup', ['initial']),
#     ('percentage', ['higher', 'is']), ('security software', ['aftermarket']),
#     ('RF feature', ['allows', 'requires']), ('thumb', ['spot']), ('hour', ['about', 'half']),
#     ('DVR', ['continues']), ('installation program', ['was']), ('DOWN', ['remote']),
#     ('engineering', ['industrial']), ('lack', ['disappointing']), ('life', ['decent']), ('night', ['long']),
#     ('attention', ['much']), ('AA', ['more']), ('rebate', ['was']), ('eye device', ['sweet', 'catching']),
#     ('away.There', ['complaints']), ('question', ['sounded']), ('control device', ['Best', 'remote']),
#     ('shield', ['invisible']), ('right', ['remote']), ('button layout', ['good']), ('shipping', ['free']),
#     ('cable', ['USB']), ('Nyco receiver', ['optional', 'Infrared']), ('List', ['absent']),
#     ('performance', ['terrible']), ('battery removal', ['solves']),
#     ('Harmony software', ['installed', 'original', 'failing', 'let', 'install']), ('HDTV system', ['older']),
#     ('apple keys.I', ['original', 'remote']), ('plasma TV', ['inputted']), ('computer software', ['clunky']),
#     ('Price', ['coming']), ('wizard', ['set', 'get']), ('indication', ['was']), ('Help function', ['fix']),
#     ('responsive.Second', ['more']), ('departure', ['stark']), ('practice', ['little']),
#     ('technician', ['telling']), ('hiccup', ['only']), ('port', ['USB', 'USB', 'USB']),
#     ('right.I', ['better']), ('Yamaha Y-4000', ['seems']), ('wonder', ['little']), ('amazon', ['implies']),
#     ('packaging', ['Nice']), ('state technology', ['let']), ('program', ['friendly']),
#     ('volume control', ['difficult']), ('disc icon', ['top']), ('quirk', ['shows']),
#     ('Ray player', ['turns']), ('replacement battery', ['original']), ('pile', ['growing']),
#     ('rf feature', ['downside']), ('adapter', ['USB']), ('item', ['Great']),
#     ('description', ['online', 'online']), ('news', ['good', 'time']), ('model', ['older']),
#     ('buttons-Easy', ['physical']), ('IR', ['commands']), ('extender.And', ['state']),
#     ('comment', ['final', 'life']), ('PITA', ['real']), ('switch', ['ends']),
#     ('Logitech database', ['spotty']), ('logitech', ['keeps']), ('simplicity', ['wonderful']),
#     ('*', ['nice', 'take']), ('innovation', ['past']), ('plus', ['real']), ('setup software', ['doing']),
#     ('layout', ['intuitive']), ('controlling', ['handed', 'remote']), ('sound', ['come']),
#     ('buttons.Fantastic database', ['soft']), ('need', ['emotional']), ('manual', ['good']),
#     ('success', ['huge']), ('con', ['only']), ('amp', ['Is']), ('receiver', ['turn', 'switches', 'switches']),
#     ('timeI', ['manual', 'made']), ('right disc', ['top']), ('dust', ['collecting']),
#     ('input', ['last', 'used']), ('profile', ['slim']), ('TV set', ['Is']), ('grip', ['better']),
#     ('game', ['most']), ('majority', ['vast', 'regarding']), ('setting', ['last']), ('draw', ['only']),
#     ('UPC', ['is']), ('Harmony screen', ['instructs']), ('CD player', ['multi']), ('head', ['little']),
#     ('together.I', ['pleased']), ('BEST bet', ['was']), ('ha', ['done']), ('harmony', ['do']),
#     ('Issue', ['Primary']), ('play', ['stop']), ('cardboard UPC', ['heavy']), ('nano delay', ['slight']),
#     ('retailer', ['major']), ('sound projector', ['digital']), ('combo', ['perfect']),
#     ('vol', ['blue', 'etched']), ('color', ['chrome']), ('none', ['simple']), ('PC software', ['updated']),
#     ('effect', ['full']), ('print', ['fine']), ('suggestion', ['official']), ('button response', ['slower']),
#     ('remote.The thing', ['whole']), ('settings thoughWhat', ['key']),
#     ('H1000', ['device', 'combines', 'appears']), ('work', ['added']), ('assumptions section', ['prominent']),
#     ('hill.Thank GAWD', ['steep']), ('surprise', ['nice']), ('upgrade', ['perfect']),
#     ('half', ['only', 'expensive']), ('voice', ['sounded']), ('family', ['loved']),
#     ('grasp', ['basic', 'of']), ('company', ['responsive']), ('series', ['short']), ('something', ['heavy']),
#     ('controller', ['single']), ('deal.Overall', ['big']), ('feel', ['light']), ('morning', ['following']),
#     ('cord', ['USB']), ('difference', ['What']), ('address', ['consuming']), ('package', ['slick']),
#     ('MX3000', ['remote']), ('battery technology', ['existing']), ('now.I', ['see']), ('patient', ['pretty']),
#     ('online', ['remote']), ('consensus', ['remote']), ('mode', ['USB']), ('show', ['favourite']),
#     ('answer', ['good']), ('headache', ['big']), ('RF icon', ['come']), ('explanation', ['was']),
#     ('layout design.A', ['intelligent']), ('scene', ['next']), ('MODE', ['SAFE']), ('toy', ['dead']),
#     ('basis', ['daily']), ('channel', ['end']), ('andbeautiful', ['big', 'bright']),
#     ('penny.Software', ['pretty']), ('disk utility', ['open']), ('track', ['remote', 'losing']),
#     ('diode', ['little', 'stuck']), ('value', ['good']), ('cost', ['entire']), ('Truth', ['is']),
#     ('addition', ['overall', 'great']), ('Logitech product', ['unable']), ('person', ['normal']),
#     ('Searching online', ['turned']), ('stereo configuration.Lastly', ['efficient']),
#     ('desktop application', ['compatible']), ('workhorse', ['good']), ('button Volume', ['hard', 'hard']),
#     ('media system', ['complex']), ('device anywhere.This', ['said']), ('improvement', ['amazing']),
#     ('submenu', ['tiny']), ('aluminum finish', ['brushed']), ('effort', ['little']),
#     ('error', ['odd', 'grammatical']), ('fix', ['nominal', 'drops']), ('theater system', ['complex']),
#     ('THOUGHT', ['cool']), ('service', ['poor']), ('setup system', ['complex']), ('concept', ['good']),
#     ('stand', ['charging', 'handy']), ('puppy', ['slides']), ('content', ['substantial']),
#     ('camper', ['happy']), ('cable box', ['turns']), ('environment', ['powerful', 'is']), ('area', ['wrong']),
#     ('sailing', ['SMOOTH']), ('None', ['code']), ('objective', ['is']),
#     ('product execution', ['single', 'worse']), ('flexibility', ['tremendous']), ('Giz Wiz', ['loved']),
#     ('info online', ['remote']), ('product CONCEPT', ['one']), ('manufacturing cost', ['raw']),
#     ('tablet', ['cheap']), ('sense', ['common']), ('Kinda', ['fizzles']), ('rebate offer', ['latest']),
#     ('check', ['double']), ('programing', ['Basic', 'simple']), ('rap', ['bad']), ('rock', ['does']),
#     ('Network receiver', ['controllable']), ('release', ['next']), ('constant', ['only', 'support']),
#     ('press', ['Watch']), ('inclination', ['is']), ('software/firmware', ['do']), ('listening', ['remote']),
#     ('product saver', ['real']), ('A freedom', ['more']), ('kind', ['expensive', 'remote', 'used']),
#     ('stand MUCH', ['charging', 'better']), ('user interface', ['easy']), ('needs.An quirk', ['annoying']),
#     ('review.First', ['fair']), ('expert server', ['buggy']), ('result', ['desired']),
#     ('button problem', ['is']), ('tech support', ['good', 'best']), ('remotesbattery', ['recharge']),
#     ('solution', ['only']), ('leary', ['little']), ('firmware.Set', ['recent']), ('light', ['dim']),
#     ('* time', ['remote']), ('input/output', ['incorrect', 'ask']), ('everyone', ['own']),
#     ('gift', ['early']), ('theater environment', ['complex']), ('touch screen2', ['capacitive']),
#     ('nightmare', ['begins']), ('touch screen.Hard', ['Difficult', 'initial']),
#     ('Sirius radio', ['controllable']), ('issue', ['last', 'remaining']), ('RF transmitter', ['stops']),
#     ('HTPC', ['has']), ('background', ['networking']), ('ability', ['great']),
#     ('date', ['actual', 'approaching']), ('state/setting', ['correct']),
#     ('something.The reason', ['missing']), ('time process', ['consuming', 'tedious']), ('start', ['great']),
#     ('forward.Logitech', ['straight']), ('complex', ['little']), ('time experiment', ['conuming', 'is']),
#     ('4665F screen', ['flat']), ('look', ['classy']), ('documentation', ['is']), ('conversation', ['long']),
#     ('Logitech.My problem', ['main']), ('ExtenderIn conclusion', ['useful']), ('expectation', ['wrong']),
#     ('macro setup.Other', ['special']), ('adapter-Has database', ['extensive', 'Infrared', 'USB']),
#     ('command names-Doesn', ['remote', 'truncating', 'come']), ('rebate status', ['invalid']),
#     ('policy', ['is']), ('DVD player', ['working']), ('disappointment', ['small']),
#     ('star icon', ['top', 'bottom', 'small', 'bottom', 'brings']), ('removal', ['necessitating']),
#     ('form', ['simple']), ('force', ['creative']), ('touch-screen', ['capacitive']), ('luck', ['better']),
#     ('son', ['old', 'uses'])],
#    83)),
#  ('B0007N55NM',
#   ([('quality',
#      ['seems', 'audio', 'loud', 'excellent', 'impressive', 'decent', 'positive', 'good', 'Bad', 'Sound',
#       'low', 'poor', 'poor', 'great', 'bad', 'great', 'seemed', 'poor', 'Good', 'includes', 'good', 'good',
#       'Terrible', 'lacks', 'great', 'poorest', 'best', 'Good', 'fit', 'good', 'great', 'great', 'audio']),
#     ('sound',
#      ['Great', 'Balanced', 'airy', 'amazing', 'treble', 'adequate', 'clearer', 'thing', 'Excellent',
#       'annoying', 'full', 'greatest', 'clear', 'great', 'good', 'better', 'great', 'crisp', 'strong',
#       'clear']),
#     ('cord',
#      ['long', 'long', 'length', 'long', 'long', 'way', 'started', 'came', 'LONG', 'feet', 'long', 'get',
#       'long', 'enough', 'bit', 'pleased']),
#     ('bass',
#      ['decent', 'high', 'awesome', 'deep', 'smooth', 'come', 'is', 'more', 'deep', 'all', 'loud',
#       'incredible']),
#     ('thing', ['annoying', 'is', 'main', 'quality', 'bad', 'amazing', 'good']),
#     ('plastic', ['feels', 'resistent', 'hard', 'hard', 'cheap']),
#     ('headphone', ['have', 'standard', 'plugs', 'smaller', 'go', 'set', 'Garbage']),
#     ('volume', ['comfortable', 'more', 'low', 'extreme', 'work']),
#     ('job', ['better', 'build', 'Great', 'fine', 'great', 'better']),
#     ('something', ['different', 'happening', 'cheap', 'professional']),
#     ('range', ['clear', 'mid', 'overall', 'excellent', 'maximum']),
#     ('length', ['perfect', 'long', 'ideal', 'Good']),
#     ('price', ['Great', 'wonderful', 'gone', 'raised', 'high']), ('side', ['went', 'go', 'good', 'work']),
#     ('treble', ['nice', 'present', 'much']), ('headband', ['starts', 'leave', 'broke']),
#     ('value', ['great', 'great', 'excellent']), ('chord', ['Long', 'nice', 'a', 'duty', 'long']),
#     ('anyone', ['allows', 'seeking', 'buy']), ('everyone', ['knows', 'saying', 'wear']),
#     ('pair', ['broke', 'fifth', 'current', 'break', 'comes', 'old', 'cheap']),
#     ('isolation', ['perfect', 'good', 'is', 'good']), ('buy', ['bad', 'good', 'good']),
#     ('product', ['amazing', 'amazing', 'great']), ('time', ['shipping', 'fast', 'long']),
#     ('music', ['oriented', 'good', 'sounded']), ('cable', ['is', 'confortable', 'long']),
#     ('noise', ['fancy', 'noticeable', 'static', 'is']), ('downside', ['bass', 'only', 'is']),
#     ('ear', ['entire', 'fitting']), ('imaging', ['good', 'vocabulary']),
#     ('listening', ['portable', 'general']), ('Sound', ['has', 'airy', 'clean']),
#     ('name', ['Gibbs', 'headphones']), ('headset', ['feels', 'makes']), ('point', ['next', 'Most']),
#     ('wire', ['Long', 'long']), ('head', ['looks', 'big']), ('fidelity', ['unmatched', 'have']),
#     ('mon', ['drum']), ('buyer', ['average']), ('audio equipment', ['expensive']), ('plug', ['plugs']),
#     ('deal', ['was']), ('wind', ['blow']), ('application', ['pro']), ('inch', ['thats']),
#     ('reason', ['only']), ('headphones.EDIT', ['inexpensive']), ('tuning guitar', ['electric']),
#     ('guitar', ['old']), ('connection', ['stopped']), ('research', ['quick']), ('effort', ['honest']),
#     ('place', ['safe']), ('upgrade', ['definite']), ('Long cord', ['heavy']), ('Outlet store', ['had']),
#     ('part', ['top', 'plastic']), ('company', ['makes']), ('volume way', ['ipod']), ('midrange', ['distant']),
#     ('emergency replacement', ['cheap']), ('speaker', ['Cheap', 'cheap', 'cheap']), ('slack', ['enough']),
#     ('imd', ['noticeable']), ('freedom', ['relative']), ('Comfort', ['must']), ('use', ['prolonged']),
#     ('nothing earth', ['shattering']), ('frequency', ['yield']), ('fitting', ['more']),
#     ('splitter', ['audio']), ('frequency response', ['great']), ('volume midrange', ['modest']),
#     ('studio edition', ['sony']), ('preference', ['listening']), ('headphones.The quality', ['plastic']),
#     ('music listening', ['casual']), ('package', ['cheap']), ('game mode', ['play']),
#     ('recording', ['musical']), ('abuse.I', ['regular']), ('sound card', ['high']), ('seat lol', ['back']),
#     ('cable length', ['long']), ('cost', ['low']), ('ft.', ['got']), ('usage', ['light']),
#     ('person', ['third', 'connect']), ('period', ['extended']), ('truck', ['powerful', 'get']),
#     ('headphone frame', ['feel']), ('abuse', ['much']), ('weight', ['bothered']), ('amount', ['decent']),
#     ('side cable', ['Dual']), ('lesson', ['learned']), ('care ofCONS', ['taken']),
#     ('custom building', ['audio']), ('discomfort', ['utmost']), ('step', ['giant']),
#     ('equalizer', ['proper']), ('player', ['portable']), ('foam padding', ['encases']),
#     ('headphone jack', ['standard']), ('adapter', ['is', 'large', 'fat', 'normal']), ('feeling', ['Cheap']),
#     ('source', ['good']), ('headphones.Comfort', ['durable']), ('punto', ['un']), ('grip', ['nice']),
#     ('padding', ['soft']), ('star performance', ['good']), ('noise technology', ['canceling']),
#     ('difference', ['big', 'was']), ('quality set', ['professional']),
#     ('construction', ['good', 'actual', 'suffer']), ('replacement', ['gets']), ('signal', ['makes']),
#     ('Sheriff', ['year', 'old']), ('band recording', ['big']), ('keyboard', ['accept']),
#     ('review.Overall', ['proper', 'audio']), ('stage placement', ['proper']), ('cord btw', ['tangled']),
#     ('fact', ['means']), ('XD100', ['better']), ('level', ['nice']), ('note', ['low']),
#     ('nothing playing', ['is']), ('mm', ['free']), ('kind', ['DJs']), ('quality sound', ['Good', 'fits']),
#     ('techno', ['overemphasize']), ('way', ['good']), ('bass response', ['poor']), (';-RRB-', ['small']),
#     ('sony', ['makes']), ('complaint', ['only', 'w']), ('duty', ['heavy']), ('set', ['cheap']),
#     ('audio', ['class']), ('fit', ['Comfortable']), ('question', ['only', 'is']), ('wire/cord', ['long']),
#     ('noise insulation', ['efficient']), ('end headphone', ['high']), ('power', ['more', 'available']),
#     ('gripe', ['only', 'plastic']), ('bass sound', ['present', 'little']), ('output', ['ban']),
#     ('bass sound-great', ['decent']), ('item', ['good']), ('comfort', ['vital']), ('merchandise', ['retail']),
#     ('manufacturing', ['cheap']), ('depth', ['much']), ('transcription', ['medical']),
#     ('hearing quality', ['higher']), ('IMHO', ['features']), ('Sony MDR-V250s', ['expensive']),
#     ('model', ['old']), ('audio jack', ['modern']), ('materials.When', ['cheap', 'cheap']),
#     ('everybody', ['listen']), ('experience', ['bad']), ('box', ['open']),
#     ('QUALITY.Having', ['LASTING', 'said']), ('feature', ['important', 'cord']),
#     ('information', ['online', 'lists']), ('id', ['try']), ('HUGE difference.I', ['recommend']),
#     ('material', ['looks']), ('line', ['professional']), ('purchase', ['OK']), ('off.I', ['pair']),
#     ('care ofchord', ['taken', 'long']), ('bass.Now', ['definite']), ('have.The unit', ['have']),
#     ('ocean', ['negative']), ('option', ['bad']), ('VOLUME CONTROL.Two', ['features']),
#     ('platicky.OVER ALL', ['Quite']), ('pick', ['great']), ('draw', ['high']), ('Apple fan', ['huge']),
#     ('son', ['Sheriff']), ('purchasing', ['worth'])],
#    80))]

# %%
# Cleaning/preprocessing: remove negation

for feature_modifier_list, _ in product_dict.values():
    for feature, modifiers in feature_modifier_list:
        for i, mod in enumerate(modifiers):
            if mod[0] == "*": # remove negation
                modifiers[i] = mod[1:]

# %%
# Finds the most mentioned features across all *products*
from collections import Counter

def get_frequent_features_products():
    feature_counts = Counter()
    for feature_modifier_list, _ in product_dict.values():
        for feature, _ in feature_modifier_list:
            feature_counts[feature] += 1
    return feature_counts

print("Total products: {0}".format(len(product_dict)))
#pp.pprint(get_frequent_features_products())
# Out:
# Total products: 7

# %%
# Finds most mentioned features across all *reviews*

def get_frequent_features_reviews():
    feature_counts = Counter()
    for feature_modifier_list, _ in product_dict.values():
        for feature, modifiers in feature_modifier_list:
            feature_counts[feature] += len(modifiers)
    return feature_counts
        
#pp.pprint(get_frequent_features_reviews())

# %%
# Finds most mentioned adjectives across all reviews
def get_frequent_adjs():
    modifier_counts = Counter()
    for feature_modifier_list, _ in product_dict.values():
        for _, modifiers in feature_modifier_list:
            for mod in modifiers:
                modifier_counts[mod] += 1
    return modifier_counts

modifier_counts = get_frequent_adjs()
print("Total modifiers: {}".format(len(modifier_counts)))
#pp.pprint(modifier_counts)
# Out:
# Total modifiers: 1503

# %%
# Returns a counter of all distinct modifiers used to describe this feature across all reviews
def get_all_modifiers(feature):
    all_modifiers = Counter()
    for feature_modifier_list, _ in product_dict.values():
        for curr_feature, modifiers in feature_modifier_list:
            if curr_feature == feature:
                for modifier in modifiers:
                    all_modifiers[modifier] += 1
    return all_modifiers

#pp.pprint(get_all_modifiers("lens"))

# %%
def get_adjs_above_threshold(counter, threshold):
    total_count = sum(counter.values())
    curr_count = 0
    adjs = set()
    for adj, count in counter.most_common():
        curr_count += count
        adjs.add(adj)
        if curr_count * 1.0 / total_count >= threshold:
            break
    return adjs

# %%
import nltk
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn

# Returns 1 minus obj score or max of abs of all pos/neg scores. All 0's if no synsets.
def get_adj_subjectivity(adj):
    ss_count = 0
    total_obj = 0
    for ss in wn.synsets(adj):
        if ss.pos() == "a" or ss.pos() == "s":
            ss_count += 1
            bd = swn.senti_synset(ss.name())
            total_obj += bd.obj_score()
            #print(ss.name(), ss.definition())
    if ss_count == 0:
        avg_obj = 2 # Make result be -1 if lookup fails
    else:
        avg_obj = round(total_obj * 1.0 / ss_count, 3)
    #print("{3} / subj: {2}".format(avg_scores[0], avg_scores[1], 1-avg_scores[2], adj))
    return 1-avg_obj

#get_adj_subjectivity("different")

# %%
# Determine whether feature is valid or not by analyzing adjs
def analyze_feature_subjectivity(feature):
    counter = get_all_modifiers(feature)
    top_adjs = get_adjs_above_threshold(counter, 0.5)
    for adj in top_adjs:
        get_adj_subjectivity(adj)

# %%
'''
Determine set of non-sentiment bearing adjectives
From plugging in diff intervals, 0.2 seems like a good number
(better to be conservative and manually add to blacklist)
'''
import math

def bucket_adjs_by_objectivity(interval, num_adjs):
    buckets = []
    num_intervals = round(1.0 / interval)
    for _ in range(num_intervals):
        buckets.append(set())
    for adj, _ in modifier_counts.most_common(num_adjs):
        subj_score = get_adj_subjectivity(adj)
        if subj_score < 0:
            bucket_num = 0
        elif subj_score == 1:
            bucket_num = -1
        else:
            bucket_num = math.floor(subj_score / interval)
        buckets[bucket_num].add(adj)
    return buckets

buckets = bucket_adjs_by_objectivity(0.2, len(modifier_counts)) # do len(modifier_counts) for all adjs
adj_filter = set(buckets[0])
print("# adjectives in lowest bucket: {}".format(len(buckets[0])))
#pp.pprint(buckets)
# Out:
# # adjectives in lowest bucket: 961

# %%
# Manually add some adjectives to filter, went through top 100 adjs using this function

def get_associated_features(adj):
    feature_counter = Counter()
    for feature_modifier_list, _ in product_dict.values():
        for feature, modifiers in feature_modifier_list:
            for mod in modifiers:
                if mod == adj:
                    feature_counter[feature] += 1
    return feature_counter

adj_filter.update(["main", "manual", "new", "original", "right", "last", "different", "other", "sound", "usb"])

# %%
# Remove adjs in filter

print("# adjs in filter: {}".format(len(adj_filter)))

for asin, (feature_modifier_list, count) in product_dict.items():
    new_list = []
    for i, (feature, modifiers) in enumerate(feature_modifier_list):
        filtered_modifiers = [x for x in modifiers if x not in adj_filter]
        if len(filtered_modifiers) > 0:
            new_list.append((feature, filtered_modifiers))
        product_dict[asin] = new_list, count

#pp.pprint(get_frequent_features_reviews())
# Out:
# # adjs in filter: 971

# %%
# Hand-pick noun filter (looked at all with over 50 adjs)
# TODO: take into account compound noun phrases

#pp.pprint(get_all_modifiers("lot"))
noun_filter = {"product", "thing", "unit", "deal", "way", "size", "job", "use", "buy", "problem", "choice",
               "something", "amount", "side", "end", "nothing", "review", "version", "idea", "solution", "difference",
               "anything", "addition", "music", "work", "head", "reason", "day", "room", "stuff", "point", "line",
               "everything", "year", "luck", "issue", "option", "place", "user", "complaint", "touch", "one",
               "number", "experience", "card", "company", "effect", "bit", "money", "view", "look", "hand", "time"}
noun_filter.update(["device", "pair", "set", "piece", "item", "player", "purchase", "headset", "earbuds",
                    "headphones", "computer", "router", "system", "machine", "tool", "model", "radio"])

# %%
# Apply noun filter
for asin, (feature_modifier_list, count) in product_dict.items():
    product_dict[asin] = [(feat, adjs) for (feat, adjs) in feature_modifier_list if feat not in noun_filter], count
    
#pp.pprint(get_frequent_features_reviews())

# %%
# Final cleanup: sort and remove features below a certain threshold

threshold = 0.02
for asin, (feat_mod_list, count) in product_dict.items():
    feat_mod_list = [(feat, adjs) for (feat, adjs) in feat_mod_list if len(adjs) * 1.0 / count >= threshold]
    product_dict[asin] = sorted(feat_mod_list, key=lambda tup: len(tup[1]), reverse=True), count

# %%
with open("./results/bad_products_improved_features.pickle", "wb") as file:
    pickle.dump(product_dict, file, 0)
