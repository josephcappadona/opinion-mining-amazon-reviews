# %%
from pycorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP('http://localhost:9000')
text = 'The picture quality is great, but the value was bad. The poor battery life was disappointing. I hate the crappy battery life.'
output = nlp.annotate(text, properties = {
    'annotators': 'pos,depparse',
    'outputFormat': 'json'
})
#output['sentences'][2]['basicDependencies']
#output['sentences'][2]['tokens']

# %%
# Adding some rules to exclude amod relationships
# Maybe try using a whitelist (known sentiment-bearing terms) instead of a blacklist
# CoreNLP doesn't parse 'sound quality' correctly, so exclude it for now...
adj_exclude = {'first', 'second', 'new', 'extra', 'previous', 'spare', 'other', 'same', 'died', 'outside',
               'ambient', 'external', 'sound', 'left', 'right', 'similar', 'wireless'}

# %%
from collections import defaultdict, Counter

def parse_corenlp_deps(sentence_json):
    adj_dict = defaultdict(list)
    for sentence in sentence_json:
        dep_list = sentence['basicDependencies']
        pos_list = sentence['tokens'] #Format is a list of objects with 'index' starting at 1
        phrase_dict = defaultdict()
        for dep in dep_list:
            if dep['dep'] == 'compound':
                phrase = dep['dependentGloss'] + ' ' + dep['governorGloss']
                phrase_dict[dep['governorGloss']] = phrase
        for dep in dep_list:
            if dep['dep'] == 'nsubj':
                noun = dep['dependentGloss']
                adj = dep['governorGloss']
                if adj in adj_exclude or not adj.isalpha():
                    continue
                pos_idx = dep['dependent']
                if pos_list[pos_idx-1]['pos'] == 'NN':
                    if noun in phrase_dict:
                        noun = phrase_dict[noun]
                    adj_dict[noun].append(adj)
            elif dep['dep'] == 'amod':
                noun = dep['governorGloss']
                adj = dep['dependentGloss']
                if adj in adj_exclude or not adj.isalpha():
                    continue
                pos_idx = dep['governor']
                if pos_list[pos_idx-1]['pos'] == 'NN':
                    if noun in phrase_dict:
                        noun = phrase_dict[noun]
                    adj_dict[noun].append(adj)
    return [tup for tup in adj_dict.items()]

# %%
import pickle
import csv
import time

# Pickle format: (list(output from nlp.annotate), list(review text))
def parse_product_csv(input_fp, output_fp):
    start = time.time()
    depparse_output = []
    corpus = []
    with open(input_fp, 'r') as csvfile:
        csvreader = csv.DictReader(csvfile, delimiter = ',')
        for row in csvreader:
            review_text = row['reviewText']
            corpus.append(review_text)
            output = nlp.annotate(review_text, properties = {
                'annotators': 'pos,depparse',
                'outputFormat': 'json'
            })
            depparse_output.append(output)
    print('Finished in %s secs' % (time.time() - start))
    with open(output_fp, 'wb') as output_file:
        pickle.dump((depparse_output, corpus), output_file)
    return depparse_output, corpus

# %%
# Actual work done here
#INPUT_FP = '../samples/earbuds_B000I68BD4_(N=1018_Stdev=1.34810039761).csv'
#INPUT_FP = '../samples/mouse_B000TG4BA0_(N=306_Stdev=1.38151831291).csv'
#INPUT_FP = '../samples/router_B000BTL0OA_(N=585_Stdev=1.15157611458).csv'
INPUT_FP = 'samples/headphones_B0001FTVEK_N=950_Stdev=1.31976200322.csv'
OUTPUT_FP = 'headphones.pkl'

# depparse_output, corpus = parse_product_csv(INPUT_FP, OUTPUT_FP)

# with open(OUTPUT_FP, "rb") as f:
#     depparse_output, corpus = pickle.load(f)

# %%
import pickle
import csv
import time

# Pickle format: (list(output from nlp.annotate), list(review text))
def parse_products(reviews, output_fp):
    start = time.time()
    depparse_output = []
    corpus = []
    for row in reviews:
        review_text = row['reviewText']
        corpus.append(review_text)
        output = nlp.annotate(review_text, properties = {
            'annotators': 'pos,depparse',
            'outputFormat': 'json'
        })
        depparse_output.append(output)
    print('Finished in %s secs' % (time.time() - start))
    with open(output_fp, 'wb') as output_file:
        pickle.dump((depparse_output, corpus), output_file)
    return depparse_output, corpus

# %%
# load reviews of top 20 asins
with open("samples/reviews_of_top_20_asins.pickle", "rb") as f:
    reviews_of_asin = pickle.load(f)

with open("samples/reviews_of_bad_products_asins.pickle", "rb") as f:
    reviews_of_asin.update(pickle.load(f))

# %%
bad_products = [
    'B0007N55NM', # headphones
    'B000II6YEA', # remote
    'B0001FV36E', # antenna
    'B00007LTBA', # router
    'B000CS1TLE', # remote
    'B000MS3VGA', # earbuds
    'B000629GES', # headphones
]

# Run Dependency parser on desired asins.
desired_asins = [
    'B00004ZCJE',
    'B00004T8R2',
    'B00001P4ZH',
    'B00005LEN4',
    'B00001WRSJ',
    'B00004ZC8Y',
    'B00005N6KG',
    'B00004Z5M1',
    'B00005ATMB',
    'B00004WCID',
#     'B00005NIMJ',
#     'B00004SB92',
#     'B00004THCZ',
#     'B00004SABB',
#     '0972683275',
#     'B00002EQCW',
#     'B00004WCIC',
#     'B00005T39Y',
#     'B00001P4XH',
#     'B00004Z5D1'
] + bad_products


# for asin in desired_asins:
    # get reviews for asin
#     output_fp = '%s_parsed_reviews.pickle' % asin
#     print('Starting to parse', asin)
#     parse_products(reviews_of_asin[asin], output_fp)

    # todo: get into good format for sumit to run sentiment shit.

# %%
import json
import gzip
import pickle

def get_review_id(review_json):
    fields = [
        'asin',
        'reviewTime',
        'reviewerID'
    ]
    return '_'.join([review_json[field] for field in fields])
   

def extract_features_with_review_id(depparse_output, reviews=None, reviews_fp=None, include_adjs=True, include_review_id=True):
    assert (not include_review_id) or (reviews or reviews_fp), 'if including review_id, reviews or reviews_fp must be provided as an argument'
    df_cnt = Counter()
    cum_adj_dict = defaultdict(list)

    if reviews:
        reviews = iter(reviews)
    elif reviews_fp:
        with open(reviews_fp, 'r') as csvfile:
            reviews = csv.DictReader(csvfile, delimiter = ',')

    for output in depparse_output:
        try:
            sentences = output['sentences']
        except:
            sentences = eval(output)['sentences']
        deps = parse_corenlp_deps(sentences)
        if include_review_id:
            review_id = get_review_id(next(reviews))

        for phrase, adjs in deps:
            if len(adjs) > 0:
                df_cnt[phrase] += 1
                if include_adjs:
                    if include_review_id:
                        cum_adj_dict[phrase].append((adjs, review_id))
                    else:
                        cum_adj_dict[phrase] += adjs
    if include_adjs:
        feat_adjs = [x for x, _ in df_cnt.most_common()]
        feat_adjs = list(map(lambda phrase: (phrase, cum_adj_dict[phrase]), feat_adjs))
        return feat_adjs
    else:
        return df_cnt
    
# Create review id -> review dict, with all review ids in desired_asins

def build_review_id_to_review_map(input_fp, mode='pickle'):
    d = {}
    count = 0
    if mode == 'json':
        reader = gzip.open(input_fp, 'r')
    elif mode == 'csv':
        with open(input_fp, 'r') as f:
            reader = csv.DictReader(f, delimiter = ',')
    elif mode == 'pickle':
        with open(input_fp, 'rb') as f:
            input_d = pickle.load(f)
        for asin_reviews in input_d.values():
            for row in asin_reviews:
                count += 1
                if count % 1000 == 0:
                    print('Processed',count)
                d[get_review_id(row)] = row
        return d

    for row in reader:
        count += 1
        if count % 1000 == 0:
            print('Processed',count)
        d[get_review_id(row)] = row
    return d


review_of_id = build_review_id_to_review_map('samples/reviews_of_top_20_asins.pickle')

# From reviews_of_asin
for asin, reviews in reviews_of_asin.items():
    for row in reviews:
        review_of_id[get_review_id(row)] = row
# Out:
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000

# %%
# Extract improved features for a given asin.

# read improved features pickle
with open("src/features/results/improved_features.pickle", "rb") as f:
    improved_features_dict_pickle = pickle.load(f)
# convert (product_quality, [modifier list]) to dict
features_of_product = defaultdict(dict)
for asin, (features, _) in improved_features_dict_pickle.items():
    for feature, adjs in features:
        features_of_product[asin][feature] = adjs

        
def load_parsed_reviews(asin):
    depparse_pickle_file = 'samples/depparse_output/%s_parsed_reviews.pickle' % asin
    with open(depparse_pickle_file, 'rb') as file:
        depparse_output, _ = pickle.load(file)
    return depparse_output

def extract_improved_features(asin):
    depparse_output = load_parsed_reviews(asin)
    yes, no = 0,0
    reviews = reviews_of_asin[asin]
    unfiltered_features_with_review_id = extract_features_with_review_id(depparse_output, reviews=reviews, include_adjs=True)
    # Filter out adjectives not in improved_features
    filtered_features = defaultdict(list)
    for feature, modifier_reviews in unfiltered_features_with_review_id:
        for (adjectives, review_id) in modifier_reviews:
            filtered_adjectives = [adj for adj in adjectives if adj in features_of_product[asin].get(feature, [])]
            if filtered_adjectives:
                filtered_features[feature].append((filtered_adjectives, review_id))
    return filtered_features

# asin = desired_asins[0]
# feat_adjs = extract_improved_features(asin)

# %%
# Pipeline to analyze new products not in improved_features.pickle

# ryin: dump unfiltered features of bad products, pass into caro's code, read in new improved features pickle for bad prods.
# product_dict: asin -> list(phrase, [adjs]), count
product_dict = {}
for asin in bad_products:
    depparse_output= load_parsed_reviews(asin)
    product_dict[asin] = (extract_features_with_review_id(depparse_output, include_review_id=False), len(depparse_output))

# dump into pickle
with open("./bad_products_features.pickle", "wb") as file:
    pickle.dump(product_dict, file, 0)

# get improved features for bad products and update
with open("src/features/results/bad_products_improved_features.pickle", "rb") as f:
    improved_features_dict_pickle = pickle.load(f)
for asin, (features, _) in improved_features_dict_pickle.items():
    for feature, adjs in features:
        features_of_product[asin][feature] = adjs

# %%
import math
import statistics
from src import sentiment
from IPython.core.debugger import set_trace


# Get sentiment for ^ output.
"""
for each product quality and adj list:
    for each (adj, helpful score, review score):
        1. find sentiment valence [-1, 1] for each adjective.
        2. weight by helpful score?

TODO:
if sentiment valence differs significantly from review score, print out
"""
def weight_score(score, review_id, mode='default'):
    """
    Returns weight of the score.

    Log weighting idea from reddit ranking algorithm:
    https://medium.com/hacking-and-gonzo/how-reddit-ranking-algorithms-work-ef111e33d0d9
    """
    if mode == 'default':
        return 1
    elif mode == 'weight_helpful':
        # TRY 1: log net helpful
        review = get_review(review_id)
        helpful = review['helpful'] if isinstance(review['helpful'], list) else json.loads(review['helpful'])
        num_helpful, num_total = helpful
        num_unhelpful = num_total - num_helpful
        net = num_helpful - num_unhelpful
        order = math.log(max(net, 2), 2)
#         order = max(net, 1)
#         print('helpful: %s/%s ==> weight: %s; score: %s' % (num_helpful, num_total, order, score))
        return order
    elif mode == 'weight_0_lower':
        # TRY 2: if 0, give it half weight.
        if score == 0:
            return 0.5
        else:
            return 1
    
    # TODO(ryin): try better heuristics


def get_review(review_id):
    return review_of_id[review_id]


def get_weighted_sentiment(product_feature_adjs, weight_mode='default'):
    """
    Returns weighted sentiment scores for each product feature of the product.
    product_feature_adjs: list of (feature, [([adjectives...], [# helpful, # unhelpful], review score)])
    
    output: [(feature, score in [-1, 1])] sorted in descending score
    """
    wc = Counter()
    total_num = total_denom = 0
    feature_scores = []
    sent_scores_of_adj = {}
    for product_quality, adj_data in product_feature_adjs:
        all_scores = []
        for adjectives, review_id in adj_data:
            scores = [sentiment.adjective.get_score(adjective) for adjective in adjectives]
            score = statistics.mean(scores)
            # TODO: print out weird ones that differ from review score, or have weird varying scores, etc
            weight = weight_score(score, review_id, mode=weight_mode)
            wc[weight] += 1
            total_num += score * weight
            total_denom += weight
            all_scores += zip(adjectives, scores)
        final_score = float(total_num) / total_denom
#         if product_quality in ['range', 'fit', 'price']:
#             set_trace()
#         print('final score for %s from %s reviews: %s' % (product_quality, len(adj_data), final_score, ))
        feature_scores.append((product_quality, final_score))
    return sorted(feature_scores, key=lambda item: item[1], reverse=True)

# %%
# Create dictionary of asin -> average review score
scores_of_asin = {}
for asin, reviews in reviews_of_asin.items():
    scores_of_asin[asin] = statistics.mean(review['overall'] for review in reviews)

# %%
# Clickable asin links.

from IPython.core.display import display, HTML

def display_link(asin):
    url = 'https://www.amazon.com/dp/'+asin
    display(HTML("""<a href="%s">%s</a>""" % (url, url)))

# for asin in desired_asins:
#     display_link(asin)

# %%
# TESTING:

# Set names of products.

names = [
    'Tiffen 46mm UV Protection Filter',
    'Panasonic On-Ear Stereo Headphones RP-HT21 (Black & Silver) Lightweight and Comfortable, Powerful Bass',
    'Koss Porta Pro On Ear Headphones with Case, Black / Silver',
    'Nikon AF FX NIKKOR 50mm f/1.8D Lens with Auto Focus for Nikon DSLR Cameras',
    'Sony MDRV6 Studio Monitor Headphones with CCAW Voice Coil',
    'Tiffen 46mm Circular Polarizer',
    'Sony MDR-W08L Vertical In-The-Ear Headphones',
    'Belkin Hi-Speed USB A/B Cable, USB Type-A and USB Type-B (10 Feet)',
    'Case Logic CDW-32 32 Capacity Classic CD Wallet (Black)',
    'Canon Remote Switch RS60 E3',
    
    # bad products
    'Sony MDR-XD100 Stereo Headphones', 
    'Logitech Harmony 1000 Advanced Universal Remote (Silver)',
    'Terk Technology HDTVi VHF/UHF HDTV Indoor Antenna',
    'D-Link DI-624 Wireless Cable/DSL Router, 4-Port Switch, 802.11g, 108Mbps',
    'Logitech Harmony 890 Advanced Universal Remote Control',
    'V-MODA Vibe In-Ear Noise-Isolating Metal Headphone (Blush)',
    'Sony MDR-NC6 Noise Canceling Headphones ',
]

asin_to_name = {asin: name for asin, name in zip(desired_asins, names)}

# SET OF HEADPHONES ASINS FOR COMPARISON!
headphones_asins = []
for i,x in enumerate(names):
    if 'headphone' in x.lower():
        headphones_asins.append(desired_asins[i])
    
headphones_asins
# Out:
# ['B00004T8R2',
#  'B00001P4ZH',
#  'B00001WRSJ',
#  'B00005N6KG',
#  'B0007N55NM',
#  'B000MS3VGA',
#  'B000629GES']

# %%
import importlib
importlib.reload(sentiment)


# Printing out results
ws_of_asin = {}
for asin in desired_asins:
    print('\n============\n')
    print('%s (ASIN: %s; overall: %.3f)\n\n' % (asin_to_name[asin], asin, scores_of_asin[asin]))
    # get review score
    feat_adjs = extract_improved_features(asin)
    weighted_sentiment = get_weighted_sentiment(feat_adjs.items(), weight_mode='weight_helpful')
    ws_of_asin[asin] = weighted_sentiment
    for feat, score in weighted_sentiment[:20]:
        print('%s: %.3f' % (feat, score))
# Out:
# ============
#
# Tiffen 46mm UV Protection Filter (ASIN: B00004ZCJE; overall: 4.282)
#
#
# price: 0.275
# protection: 0.233
# uv filter: 0.225
# quality: 0.225
# glass: 0.218
# lens: 0.203
# filter: 0.197
#
# ============
#
# Panasonic On-Ear Stereo Headphones RP-HT21 (Black & Silver) Lightweight and Comfortable, Powerful Bass (ASIN: B00004T8R2; overall: 4.379)
#
#
# sound: 0.306
# bass: 0.280
# headphone: 0.276
# value: 0.244
# quality: 0.239
# weight: 0.219
# fit: 0.165
# volume: 0.139
# cord: 0.124
# price: 0.104
#
# ============
#
# Koss Porta Pro On Ear Headphones with Case, Black / Silver (ASIN: B00001P4ZH; overall: 4.465)
#
#
# sound: 0.325
# design: 0.294
# setting: 0.278
# value: 0.275
# quality: 0.274
# bass: 0.268
# weight: 0.262
# case: 0.254
# headphone: 0.249
# price: 0.168
# range: 0.154
# fit: 0.145
#
# ============
#
# Nikon AF FX NIKKOR 50mm f/1.8D Lens with Auto Focus for Nikon DSLR Cameras (ASIN: B00005LEN4; overall: 4.752)
#
#
# bokeh: 0.235
# image quality: 0.220
# depth: 0.215
# photography: 0.213
# lens: 0.212
# picture: 0.183
# value: 0.182
# quality: 0.172
# portrait lens: 0.171
# focus: 0.171
# light: 0.170
# image: 0.166
# aperture: 0.160
# price: 0.066
#
# ============
#
# Sony MDRV6 Studio Monitor Headphones with CCAW Voice Coil (ASIN: B00001WRSJ; overall: 4.630)
#
#
# sound: 0.288
# value: 0.270
# quality: 0.234
# headphone: 0.227
# bass: 0.226
# response: 0.223
# price: 0.154
# design: 0.134
# cord: 0.103
#
# ============
#
# Tiffen 46mm Circular Polarizer (ASIN: B00004ZC8Y; overall: 4.392)
#
#
# value: 0.279
# quality: 0.260
# sky: 0.244
# filter: 0.220
# price: 0.207
# lens: 0.182
#
# ============
#
# Sony MDR-W08L Vertical In-The-Ear Headphones (ASIN: B00005N6KG; overall: 4.072)
#
#
# sound: 0.258
# quality: 0.218
# design: 0.190
# bass: 0.187
# weight: 0.185
# cord: 0.117
# price: 0.065
#
# ============
#
# Belkin Hi-Speed USB A/B Cable, USB Type-A and USB Type-B (10 Feet) (ASIN: B00004Z5M1; overall: 4.681)
#
#
# price: 0.409
# length: 0.367
# quality: 0.351
# brand: 0.349
# cable: 0.332
# cord: 0.316
#
# ============
#
# Case Logic CDW-32 32 Capacity Classic CD Wallet (Black) (ASIN: B00005ATMB; overall: 4.458)
#
#
# price: 0.377
# quality: 0.266
# wallet: 0.224
# case: 0.174
# storage: 0.163
# zipper: 0.132
#
# ============
#
# Canon Remote Switch RS60 E3 (ASIN: B00004WCID; overall: 4.592)
#
#
# price: 0.492
# switch: 0.390
# shutter: 0.189
# camera: 0.154
# length: 0.146
# accessory: 0.137
# exposure: 0.132
# cord: 0.103
# cable: 0.099
#
# ============
#
# Sony MDR-XD100 Stereo Headphones (ASIN: B0007N55NM; overall: 3.275)
#
#
# range: 0.307
# price: 0.299
# volume: 0.265
# adapter: 0.239
# value: 0.221
# sound: 0.213
# bass: 0.209
# construction: 0.206
# isolation: 0.206
# wire: 0.205
# headphone: 0.200
# materials.When: 0.199
# length: 0.198
# quality: 0.193
# care ofchord: 0.191
# plastic: 0.182
# chord: 0.181
# noise: 0.178
# cord: 0.157
# Sound: 0.154
#
# ============
#
# Logitech Harmony 1000 Advanced Universal Remote (Silver) (ASIN: B000II6YEA; overall: 3.398)
#
#
# tech support: 0.298
# touch screen: 0.289
# range: 0.250
# style: 0.215
# Programming: 0.210
# touchscreen: 0.209
# display: 0.207
# angle: 0.204
# battery life: 0.201
# setup: 0.198
# design: 0.183
# software: 0.183
# star icon: 0.182
# customer support: 0.177
# andbeautiful: 0.173
# set-up: 0.172
# connection: 0.172
# button: 0.172
# price: 0.168
# eye device: 0.158
#
# ============
#
# Terk Technology HDTVi VHF/UHF HDTV Indoor Antenna (ASIN: B0001FV36E; overall: 3.404)
#
#
# antenna: 0.128
# signal strength: 0.127
# attic antenna: 0.122
# gain antenna: 0.121
# TERK antenna: 0.120
# rabbit ear: 0.119
# reception: 0.119
# surface: 0.118
# Reception: 0.117
# quality: 0.106
# HD signal: 0.105
# area: 0.103
# NBC signal: 0.103
# programming: 0.101
# type antenna: 0.100
# Terk antenna: 0.099
# signal: 0.082
# base: 0.071
# HD antenna: -0.105
# TV preamplifier: -0.116
#
# ============
#
# D-Link DI-624 Wireless Cable/DSL Router, 4-Port Switch, 802.11g, 108Mbps (ASIN: B00007LTBA; overall: 3.423)
#
#
# signal: 0.337
# price: 0.332
# setup: 0.310
# range: 0.306
# speed: 0.305
# tech: 0.297
# connection: 0.264
#
# ============
#
# Logitech Harmony 890 Advanced Universal Remote Control (ASIN: B000CS1TLE; overall: 3.437)
#
#
# price: 0.535
# support: 0.398
# battery: 0.129
# tooth: 0.124
# part: 0.091
# configuration: 0.091
# hardware: 0.084
# setup: 0.081
# software: 0.074
# screen: 0.056
# Harmony: 0.051
# customer service: 0.049
# performance: 0.046
# documentation: 0.041
# connection: 0.039
# help: 0.035
# charger: 0.023
#
# ============
#
# V-MODA Vibe In-Ear Noise-Isolating Metal Headphone (Blush) (ASIN: B000MS3VGA; overall: 3.457)
#
#
# price: 0.519
# fit: 0.392
# commute: 0.346
# midrange: 0.324
# highs/mid: 0.253
# quality.I: 0.252
# shock: 0.252
# quality: 0.252
# seal: 0.250
# shape: 0.250
# lack: 0.249
# sound: 0.247
# headphone: 0.245
# high: 0.245
# cord: 0.242
# medium: 0.223
# part: 0.199
# PROBLEM: 0.185
# sound level: 0.172
# clarity: 0.170
#
# ============
#
# Sony MDR-NC6 Noise Canceling Headphones  (ASIN: B000629GES; overall: 3.457)
#
#
# noise canceling: 0.395
# price: 0.276
# range: 0.275
# hiss: 0.216
# quality: 0.161
# bass: 0.158
# volume: 0.154
# headphone: 0.146
# flight: 0.146
# level: 0.144
# sound: 0.142
# noise cancellation: 0.132
# pouch: 0.128
# design: 0.128
# noise: 0.124
# background noise: 0.121
# plastic: 0.118
# sound value: 0.117

# %%
# compare shared features for group.
shared_features = {feat for feat, _ in ws_of_asin[headphones_asins[0]]}
for asin in headphones_asins[1:]:
    shared_features = shared_features.intersection({feat for feat, _ in ws_of_asin[asin]})

# For each shared feature, show the sentiment of each product.

for asin in sorted(headphones_asins, key=lambda asin: scores_of_asin[asin], reverse=True):
    print('\n===== \n\n%s (ASIN: %s; overall: %.3f)\n\n' % (asin_to_name[asin], asin, scores_of_asin[asin]))
    weighted_sentiment = ws_of_asin[asin]
    for feat, score in sorted(ws_of_asin[asin]):
        if feat in shared_features:
            print('%s: %.3f' % (feat, score))
# Out:
# =====
#
# Sony MDRV6 Studio Monitor Headphones with CCAW Voice Coil (ASIN: B00001WRSJ; overall: 4.630)
#
#
# bass: 0.235
# price: 0.183
# quality: 0.259
# sound: 0.300
#
# =====
#
# Koss Porta Pro On Ear Headphones with Case, Black / Silver (ASIN: B00001P4ZH; overall: 4.465)
#
#
# bass: 0.275
# price: 0.225
# quality: 0.290
# sound: 0.338
#
# =====
#
# Panasonic On-Ear Stereo Headphones RP-HT21 (Black & Silver) Lightweight and Comfortable, Powerful Bass (ASIN: B00004T8R2; overall: 4.379)
#
#
# bass: 0.263
# price: 0.109
# quality: 0.237
# sound: 0.295
#
# =====
#
# Sony MDR-W08L Vertical In-The-Ear Headphones (ASIN: B00005N6KG; overall: 4.072)
#
#
# bass: 0.213
# price: 0.070
# quality: 0.251
# sound: 0.262
#
# =====
#
# Sony MDR-NC6 Noise Canceling Headphones  (ASIN: B000629GES; overall: 3.457)
#
#
# bass: 0.161
# price: 0.274
# quality: 0.174
# sound: 0.153
#
# =====
#
# V-MODA Vibe In-Ear Noise-Isolating Metal Headphone (Blush) (ASIN: B000MS3VGA; overall: 3.457)
#
#
# bass: 0.177
# price: 0.519
# quality: 0.257
# sound: 0.254
#
# =====
#
# Sony MDR-XD100 Stereo Headphones (ASIN: B0007N55NM; overall: 3.275)
#
#
# bass: 0.218
# price: 0.299
# quality: 0.202
# sound: 0.233

# %%
# For each shared feature, show the sentiment of each product.

print('Cross-section of headphones products and shared features')
for feat in shared_features:
    print('\n=============\nFeature:', feat)
    
    l = []
    for asin in headphones_asins:
        for f, score in sorted(ws_of_asin[asin]):
            if f == feat:
                l.append('%.3f (star rating: %.3f)' % (score, scores_of_asin[asin]))

    for s in sorted(l, reverse=True):
        print(s)
# Out:
# Cross-section of headphones products and shared features
#
# =============
# Feature: price
# 0.519 (star rating: 3.457)
# 0.299 (star rating: 3.275)
# 0.274 (star rating: 3.457)
# 0.225 (star rating: 4.465)
# 0.183 (star rating: 4.630)
# 0.109 (star rating: 4.379)
# 0.070 (star rating: 4.072)
#
# =============
# Feature: bass
# 0.275 (star rating: 4.465)
# 0.263 (star rating: 4.379)
# 0.235 (star rating: 4.630)
# 0.218 (star rating: 3.275)
# 0.213 (star rating: 4.072)
# 0.177 (star rating: 3.457)
# 0.161 (star rating: 3.457)
#
# =============
# Feature: sound
# 0.338 (star rating: 4.465)
# 0.300 (star rating: 4.630)
# 0.295 (star rating: 4.379)
# 0.262 (star rating: 4.072)
# 0.254 (star rating: 3.457)
# 0.233 (star rating: 3.275)
# 0.153 (star rating: 3.457)
#
# =============
# Feature: quality
# 0.290 (star rating: 4.465)
# 0.259 (star rating: 4.630)
# 0.257 (star rating: 3.457)
# 0.251 (star rating: 4.072)
# 0.237 (star rating: 4.379)
# 0.202 (star rating: 3.275)
# 0.174 (star rating: 3.457)

# %%
# Finding review text snippets for particular adjectives of a review.

def find_review_text(feature, adjective, review_id):
    """Returns snippets of review text given feature, adjective and review_id (see get_review_id).
    
    """
    review = get_review(review_id)
    review_text_lines = review['reviewText'].split('.')
    for i, line in enumerate(review_text_lines):
        if adjective in line and feature in line:
            return line

# Sample review text snippets!
import random

asin = desired_asins[4]
for asin in desired_asins:
    improved_features = extract_improved_features(asin)
    # Randomly choose features and adjectives to show
    for feature, modifiers in improved_features.items():
        for adjs, review_id in modifiers:
            for adj in adjs:
                if sentiment.adjective.get_score(adj) < 0:
                    print('Evidence for %s %s: \n\n %s \n\n' % (adj, feature, find_review_text(feature, adj, review_id)))
# Out:
# Evidence for low price:
#
#  I wanted lense protection at a very low price
#
#
# Evidence for low price:
#
#   This one is a mid-grade quality filter at a very low price
#
#
# Evidence for low price:
#
#  5mm UV Filter I could find on Amazon at a low price
#
#
# Evidence for low price:
#
#  Such a low price for a UV filter
#
#
# Evidence for low price:
#
#    Not one of the classiest filters I've owned - but it does the job I want it to do and at a very low price
#
#
# Evidence for low price:
#
#  Right now 4 stars seems fine, mainly because it is good quality at a very low price
#
#
# Evidence for low price:
#
#   High quality at a low price
#
#
# Evidence for low price:
#
#    For some of my more expensive lenses I've gone with Hoya multi-coated or B&W filters but the bottom line is this Tiffen filter works good for a low price like $13
#
#
# Evidence for low price:
#
#    I was a little uncertain of the quality, because of the low price, ( 1/3 the cost of Vivtar or Nikon equivalents), but after receiving them and inspected them they look great
#
#
# Evidence for loose lens:
#
#   The lens is loose in the ring housing, so there is a slight rattle when shaken
#
#
# Evidence for useless filter:
#
#  Don't waste your $10!! I'm not a prosumer even, but the blue ghosting/flare is very noticeable on half my photos! This cheap filter is useless, I can't see anyone using it for more than a couple of weeks
#
#
# Evidence for bad filter:
#
#    This is not a bad filter by any means, but if you have a good lens, you owe it to yourself to get a better filter - you'll see the difference
#
#
# Evidence for useless filter:
#
#   This filter is totally useless if you pointed against any kind of light source
#
#
# Evidence for bad filter:
#
#   And they work great for that and they aren't a bad filter for shooting outdoors; but almost the second you move inside you will start getting light flare on your pictures
#
#
# Evidence for broke filter:
#
#  I bought this filter for my lens when my old filter broke
#
#
# Evidence for disappointed filter:
#
#  This filter has not disappointed and was exactly right for my Sony Alpha A200 camera
#
#
# Evidence for broke filter:
#
#  our older filter broke when my 7 year old dropped the camera (quite by accident)
#
#
# Evidence for broke filter:
#
#   the filter broke but the lens glass didn't even have a crack in it
#
#
# Evidence for bad filter:
#
#  ok it could happen i got the one bad filter on the rack, but unlikely
#
#
# Evidence for loose filter:
#
#  Arrived quickly, Packaged well but the filter itself was loose in the case
#
#
# Evidence for dirty filter:
#
#  As someone else commented, the filter was dirty with it arrived
#
#
# Evidence for worst quality:
#
#  Very simple , don't not buy , it made in US but the quality is worst
#
#
# Evidence for loose glass:
#
#    One filter did arrive broken, but it looked like someone may have broken it, and returned it to amazon, and they didn't check it well enough when it got returned (you had to pick it up and jiggle it to realize the glass was loose) before it was sent out again and I got it
#
#
# Evidence for lower glass:
#
#   the glass doesn't lower the quality so no worries about that
#
#
# Evidence for shattered glass:
#
#  The glass on the UV protector shattered, but the lens seems fine
#
#
# Evidence for loose glass:
#
#    The glass in the metal ring however is loose and does not exude quality
#
#
# Evidence for loose glass:
#
#    One filter was fine, the glass in the other filter was loose in the ring
#
#
# Evidence for low price:
#
#  The sound on these is astonishing for the ridiculously low price
#
#
# Evidence for low price:
#
#  If you want headphones that have deep base like this, and a very low price, then you should buy this product
#
#
# Evidence for low price:
#
#  One of the best headphones out there for such a low price
#
#
# Evidence for low price:
#
#   They break, you won't be too worried, but the price is so low you won't be looking to return for a refund
#
#
# Evidence for low price:
#
#    They are wonderful for people who don't like ear buds or just people who want a set of decent headphones for a low price
#
#
# Evidence for low price:
#
#  I gave these a 3 star rating but only because of the low price, otherwise a 1 or 2
#
#
# Evidence for low price:
#
#  In a nutshell - if you want a lightweight, over-the-head, great sounding set of headphones, for an insanely low price, these are the ones
#
#
# Evidence for low price:
#
#  Sound quality is ok for the low price
#
#
# Evidence for low price:
#
#    Such a low price, why not?  THIS is why not -- if all you want to hear is bass, these might be ok
#
#
# Evidence for low price:
#
#  These headphones were low price and did the basic job OK
#
#
# Evidence for low price:
#
#  I was skeptical because of the low, low price, but after reading all the reviews on Amazon I ordered these as a gift for my 88 yr old mother who needed some to watch tv late at night
#
#
# Evidence for low price:
#
#  I was skeptical because of the low, low price, but after reading all the reviews on Amazon I ordered these as a gift for my 88 yr old mother who needed some to watch tv late at night
#
#
# Evidence for low price:
#
#   You can add that the price is very low for Panasonic
#
#
# Evidence for low price:
#
#   Put them on and relax to enjoy wonderful sound quality for really low price
#
#
# Evidence for low price:
#
#  The quality of sound is acceptable, considering the low price
#
#
# Evidence for low price:
#
#  These work good for the low price, and the easy over head use, but sadly my head is way smaller than what these are intended for, wouldn't work for children then either
#
#
# Evidence for low price:
#
#  These headphones are not a pair I would be ashamed to be seen wearing in public!They are nice looking!So if you are looking for a nice, fairly stylish, comfortable pair of earphones to buy for an *EXCEPTIONALLY* low price I can recommend these
#
#
# Evidence for terrible fit:
#
#    While the sound is good, the fit is terrible
#
#
# Evidence for lower volume:
#
#   I found the sound quality of these inexpensive headphones surprisingly good, with a lot of warmth and a good amount of bass, although the output power is on the low side, which means lower volume than more expensive headphones
#
#
# Evidence for wimpy volume:
#
#    Other than the somewhat wimpy volume of them, they seem a worthwhile investment
#
#
# Evidence for low volume:
#
#    They're much too large for a child's head, the volume is too low (I didn't mind this for my kids), the sound quality at it's best is still poor, and there is horrible static every time the plug moves in the headphone jack
#
#
# Evidence for low volume:
#
#  My biggest complaint is that they don't fit snug on my head so the sound volume is very low
#
#
# Evidence for low quality:
#
#  This set is very inexpensive and I was concerned the quality would be low at best
#
#
# Evidence for poor quality:
#
#    They're much too large for a child's head, the volume is too low (I didn't mind this for my kids), the sound quality at it's best is still poor, and there is horrible static every time the plug moves in the headphone jack
#
#
# Evidence for poor quality:
#
#   I find ear-buds to be uncomfortable, and the sound to be of poor quality (no bass whatsoever and low quality high notes)
#
#
# Evidence for poor bass:
#
#   fails with the feature &#34;XBS port&#34; because the bass is fairly poor relative to almost any (even slightly) larger cupped cans
#
#
# Evidence for weak sound:
#
#    I could have kept it even though its sound is a little weak compared to the JVC, but the fit just completely turned me off
#
#
# Evidence for weak sound:
#
#   The sound is very weak compared to quite a few other equally priced headphones
#
#
# Evidence for bad sound:
#
#    I am very sensitive to bad sound
#
#
# Evidence for worst sound:
#
#  I purchased these with a few other sets of headphones and these had the worst sound out of all of them
#
#
# Evidence for serious sound:
#
#    For serious sound, my children and I rely on better quality ear buds anywhere from the $8 to $35 range
#
#
# Evidence for lower price:
#
#    If you want to demo this sound t a lower price, try out the Koss KSC 75 ear clip model, but be warned they're nowhere near as comfortable
#
#
# Evidence for low price:
#
#  Outstanding bass while keeping everything else clean, at an incredible low price; and confortable !
#
#
# Evidence for bothered price:
#
#  I was on the verge of buying Bose headphones but the price bothered me
#
#
# Evidence for low price:
#
#  I got these because the low price, good sound quality and they are collapsable
#
#
# Evidence for awkward fit:
#
#    (i've never had any luck with the awkward fit of earbuds, but i can also highly recommend The Plug by Koss if you have no problem with them -- excellent bass and highs
#
#
# Evidence for distorted sound:
#
#  I have that as good as the PortaPro's are, they give more of a distorted sound, especially with distortion at bass
#
#
# Evidence for awful sound:
#
#   Tired of the awful sound of default earbuds, I've experimented with Shure, Bose, Sennheiser,Klipsch, andJVCbrands, ranging in price from $25 to $100, but have never really been satisfied with sound signatures that were either too bass-shy, too muddy, or cramped soundstage
#
#
# Evidence for horrible sound:
#
#   And they exhibit horrible sound
#
#
# Evidence for low sound:
#
#    Very full and rich low and mid sound (not muddled but clear and balanced)
#
#
# Evidence for lost sound:
#
#  Pros-----GREAT Sound-Lifetime Warranty-Once you have them on your head and adjusted they stay thereCons-----No volume control-They press so firmly on the side of my head it gets uncomfortable after a while, even using the pressure setting switch on light-I've had them in twice for repair - lost sound on one side (for no apparent reason - I'm not hard on them and don't use them that often, only a few times a year)-Every time I take them off they lose their adjustment settings-They really need to come with a better case
#
#
# Evidence for awkward design:
#
#  I guess the style and seemingly awkward design made me initially think these headphones were a bad purchase
#
#
# Evidence for poor design:
#
#   great speakers, poor design and manufacturing
#
#
# Evidence for uncomfortable quality:
#
#  The bud type earphones just don't cut it for me - uncomfortable and sound quality just crappy
#
#
# Evidence for lousy quality:
#
#   Just not as good sounds as I thought, or maybe I just played crappy music with lousy mp3 quality, downloaded from unreliable source
#
#
# Evidence for poor quality:
#
#  Seriously, are these airplane headphones?  That's how poor I found the sound quality in these
#
#
# Evidence for poor quality:
#
#  Is there something wrong with my PortaPros?  I have no idea why there would be such dramatically poor quality in a product which most people seem to rate higher or on a par with the other phones I have
#
#
# Evidence for bad quality:
#
#   I am a guitarist and musician and use various studio monitors and get very easily disappointed by bad quality
#
#
# Evidence for unmatched bass:
#
#  I had a Koss CD player when I was little, and the bass was unmatched in a bookshelf system
#
#
# Evidence for ridiculous bass:
#
#   the sound was average and I do not understand why people say it had ridiculous bass, I don't think it did
#
#
# Evidence for poor bass:
#
#   The first set I had poor bass in the left channel, in about the sub-100Hz range
#
#
# Evidence for hard case:
#
#  I just wish Koss would send a hard case for storage since I do believe that the soft case does not protect them enough when they are stowed
#
#
# Evidence for hard case:
#
#    I wish they came with a hard case for true protection while traveling
#
#
# Evidence for hard case:
#
#    They're slightly more cumbersome to fold up and reinsert in their hard case than the PortaPro's (at least without practice), but that slight downside had never seemed more insignificant
#
#
# Evidence for hard case:
#
#   The carrying case they come with (a leatherette bag) is a slightly tight fit and I probably won't end up using it much since it is not a hard case that would protect them from shock or crushing
#
#
# Evidence for worthless case:
#
#   The case is pretty worthless and too small, but whatever, its really not necessary
#
#
# Evidence for lower price:
#
#   If you are looking for quality at a lower price, you found it
#
#
# Evidence for low price:
#
#   Despite it's low price, it's well-constructed and can handle rough use
#
#
# Evidence for low price:
#
#  Excellent value: good optics for low price
#
#
# Evidence for low price:
#
#   The distortion is minimal, the chromatic aberration is very low, the contrast is very high and the resolution is very high and the price is very low as you can see
#
#
# Evidence for low price:
#
#   For such a low price, it should be in anyone's bag
#
#
# Evidence for lower price:
#
#  4with the autofocus-motor or, if this is your first prime lens and you want a lower price, go ahead and start with the more forgiving35mm f/1
#
#
# Evidence for low price:
#
#   It's very low price in relation to it's high quality makes it a must have for anyone who needs doesn't have a good quality lens around the 50mm mark
#
#
# Evidence for low price:
#
#  I didn't buy this for the low price; I bought it for its quality at a now deeply discounted price
#
#
# Evidence for intimidating lens:
#
#  If you are into street photography,this lens is less intimidating
#
#
# Evidence for difficult lens:
#
#  One of the reviewers pointed out (Richard "the Lion Heart") that this lens is difficult to focus manually using the D40
#
#
# Evidence for difficult lens:
#
#   Gives a nice sharp image however I found the lens a little difficult to use and understand
#
#
# Evidence for limited depth:
#
#   The very limited depth of field this lens can give you is very fun to play with and offers lots of creative opportunities
#
#
# Evidence for limited depth:
#
#  Subject Motion: With such a limited depth of field, when shooting at the larger apertures, even a small bit of subject motion can cause one of two things to happen
#
#
# Evidence for hard bokeh:
#
#    The bokeh is hard as other reviewers have said so you'll want to avoid too busy of a background if you're shooting portraits
#
#
# Evidence for low light:
#
#  8D is so much sharper, cheaper, and taking images at low, very low light that I could not even image to take with my 55mm-200MM VR
#
#
# Evidence for low light:
#
#  8D is so much sharper, cheaper, and taking images at low, very low light that I could not even image to take with my 55mm-200MM VR
#
#
# Evidence for low light:
#
#   It doesn't autofocus on her camera, but having quickly learned the advantages of wide apertures, the ability to shoot in low light without flash, and the difference between razor-sharp and 'sharp enough,' she rarely takes it off her camera
#
#
# Evidence for low light:
#
#   I have posted an Orchid photograph I recently shot with no flash in low light and the image is stunning in quality, color and sharpness
#
#
# Evidence for low light:
#
#   For the majority of my shooting, which is indoor low light, photojournalism and portraits, This lens can't be beat for the price! If I want to shoot landscapes, I throw on the kit lens, but you'll find this 50mm on my D50 90% of the time
#
#
# Evidence for low light:
#
#   For the majority of my shooting, which is indoor low light, photojournalism and portraits, This lens can't be beat for the price! If I want to shoot landscapes, I throw on the kit lens, but you'll find this 50mm on my D50 90% of the time
#
#
# Evidence for low light:
#
#  This lens produces sharp pictures, is fast, works well in low light, and has nice depth of field when set at f/1
#
#
# Evidence for low light:
#
#    As the other reviews say about low light, don't believe them
#
#
# Evidence for low light:
#
#  5 had to go in for repairs a week before a wedding I was desperate for a lens to use for the reception that would give me clean pictures in low light and give me that yummy shallow depth of field I like for portraits
#
#
# Evidence for low light:
#
#   I love how well it works in low light
#
#
# Evidence for low light:
#
#   It makes shooting indoors or in low light much easier
#
#
# Evidence for low light:
#
#   I love this lens, I carry it everywhere it works great in low light, it focuses several times faster than my $850 18-200mm Nikkor lens
#
#
# Evidence for lowest light:
#
#    It's easy, amazingly clear, gets great color in the lowest light you could imagine, and I paid like $125 for it
#
#
# Evidence for low light:
#
#  Its part of my photography gear and can tell that is perfect for portraits and low light
#
#
# Evidence for low light:
#
#   It would be disappointing if one purchased this thinking that it could be used for excellent low-light photography when shot wide open at f/1
#
#
# Evidence for low light:
#
#  This lens is a MUST HAVE! I have a Nikon D7000 with a 40mm Macro, 18-200mm tele, and this 50mm prime, and out of all these tools this Nikon 50mm is the one that consistently stays as my go-to lens! Sharp picture, wonderful color recreation, great in low light! This is a must-have in anyone's DSLR camera arsenal
#
#
# Evidence for low light:
#
#  This lens is great for low light
#
#
# Evidence for low light:
#
#  The is a great lens for an armature that needs to take photos in low light
#
#
# Evidence for low light:
#
#  8 lens is ideal for the photographer who wishes to enhance his low-light photography
#
#
# Evidence for low light:
#
#   Quite useful in low light
#
#
# Evidence for low light:
#
#    It does wonders in low light compared to my kit lenses, it's built solid, and the price is wonderful
#
#
# Evidence for low light:
#
#   Very convenient to have wide f-stop for low light rather boost the ISO on my D-90
#
#
# Evidence for low light:
#
#  This is a good inexpensive portrait lens that works well in low light or with a flash
#
#
# Evidence for low light:
#
#    Even if you have other zoom lenses that cover this range as I do, this lens is unbelievably useful in low light to no light situations
#
#
# Evidence for low light:
#
#    Wonderful in low light, fast AF, and all the images are terrific
#
#
# Evidence for low light:
#
#    For portraits, close ups, low light without flash, it's a great lens
#
#
# Evidence for low light:
#
#  I'm an owner of a Nikon D90 dSLR and shopping around for prime lenses for low light and portraiture work when I came across this little bargain
#
#
# Evidence for low light:
#
#  I bought this lens for portrait photography, often in low light
#
#
# Evidence for low light:
#
#  Results: Extremely sharp lens, it loves low light, razor sharp results
#
#
# Evidence for low light:
#
#  Great in low light
#
#
# Evidence for low light:
#
#    Very fast in low light, focuses and performs super on D7000
#
#
# Evidence for low light:
#
#    It's a knockout low light performer, produces vivid colors, and is super contrasty
#
#
# Evidence for low light:
#
#    It's a knockout low light performer, produces vivid colors, and is super contrasty
#
#
# Evidence for low light:
#
#    I have used it for two specific things for which it's better than the kit zoom lenses: short depth of field and low light
#
#
# Evidence for low light:
#
#   I wanted a prime, low light lens that produces sharp, accurate pictures in low light
#
#
# Evidence for low light:
#
#    It has very good performance in low light
#
#
# Evidence for low light:
#
#  For more or less $100, all of a sudden you have subject separation and decent bokeh, a pretty fast lens in low light and in good light (giving you high shutter speeds for action) and hey, it's probably lighter than your set of car and house keys
#
#
# Evidence for low light:
#
#    Some shot does look sharp but is not worth the time to get it right, a VR Telephoto will do better in low light i compare to both
#
#
# Evidence for low light:
#
#   The lens is great for portraits, close ups, and low light no flash photography
#
#
# Evidence for low light:
#
#   I initially get this lens for low light action and sport photography (as this lens is famous for being one of the fastest lens together with its brother 50mm f/1
#
#
# Evidence for low light:
#
#  Finally purchased this to use on my D80 after reading "all" the reviews and for the price, who can complain! In a nutshell, this lens is a perfect addition to any kit offering great low light-fast shooting and excellent picture quality
#
#
# Evidence for low light:
#
#  8 is excellent for low light and images created from my D7000 blown up to extremes on the monitor show no vignetting that I can see, no chromatic aberation, and excellent contrast from center to edge
#
#
# Evidence for low light:
#
#  You buy this lens for two reasons: to shoot in low light without flash or to get great depth of field control
#
#
# Evidence for low light:
#
#  8D AF Nikkor Lens for Nikon Digital SLR CamerasThis lens is amazing in low light
#
#
# Evidence for low light:
#
#    And its great to have for special occasions with low light, I just wish I had the D90 or better so I could use all its functionality
#
#
# Evidence for low light:
#
#   It takes great quality pictures in very low light
#
#
# Evidence for low light:
#
#    It is sharp and works very well in low light
#
#
# Evidence for low light:
#
#   It seems so small and insignificant, yet produces such sharp and colorful images, especially in low light
#
#
# Evidence for difficult focus:
#
#    Shooting fast moving sports does make focus difficult and I missed a few shots I would have like to have gotten, but I got plenty of nice ones
#
#
# Evidence for low price:
#
#   Try them; I believe you'll like them, especially considering their remarkably low price
#
#
# Evidence for poor design:
#
#   Overall, a very poor design in my view
#
#
# Evidence for poor quality:
#
#   The one criticism I have of these is the poor quality of the earpads
#
#
# Evidence for low bass:
#
#   The 2014 V6 has a noticeable boost in the low bass - educated guess, about +4dB or +5dB centered broadly around 70Hz - making them a bit less suitable for studio work (monitoring/mixing/mastering) than the K701s, and about +2dB or +3dB higher in the low bass than my vintage MDR-V6 headphones were when new
#
#
# Evidence for low bass:
#
#   The 2014 V6 has a noticeable boost in the low bass - educated guess, about +4dB or +5dB centered broadly around 70Hz - making them a bit less suitable for studio work (monitoring/mixing/mastering) than the K701s, and about +2dB or +3dB higher in the low bass than my vintage MDR-V6 headphones were when new
#
#
# Evidence for low bass:
#
#   The 2014 V6 has a noticeable boost in the low bass - educated guess, about +4dB or +5dB centered broadly around 70Hz - making them a bit less suitable for studio work (monitoring/mixing/mastering) than the K701s, and about +2dB or +3dB higher in the low bass than my vintage MDR-V6 headphones were when new
#
#
# Evidence for terrible bass:
#
#   I've had bad headphones in the past that had terrible bass or treble, but for me its very well balanced
#
#
# Evidence for low bass:
#
#  Some confuse the clean extremely low bass, with exaggerated Bass
#
#
# Evidence for weak bass:
#
#    I do NOT concur with other review comments about weak bass
#
#
# Evidence for low bass:
#
#   The low bass can sometimes sound a bit punchy and thereby be a distraction
#
#
# Evidence for low sound:
#
#   The sound is great even with the volume at low  sound
#
#
# Evidence for low price:
#
#  Kinda worry when purchased it because its low price
#
#
# Evidence for loose lens:
#
#    A temporary disappointment with a significantly loose lens, however a pin inserted into the locking ring and a full circumference twist fixed the problem
#
#
# Evidence for dirty filter:
#
#  First, I suspect that I have received a used filter because the package was not sealed and the filter was dirty on both sides
#
#
# Evidence for bad filter:
#
#    This is not a bad filter, but hardly the best one out there
#
#
# Evidence for bad filter:
#
#  I must say this is not a bad filter for the money
#
#
# Evidence for bad filter:
#
#  ve never had a bad filter from tiffin
#
#
# Evidence for low price:
#
#   The clincher is the low price, so much so I bought a second one as backup
#
#
# Evidence for low price:
#
#   My initial decision to buy them was primarily influenced by their low price, and the quality was commensurate with the price
#
#
# Evidence for low price:
#
#    I don't think you will be disappointed in these, and at such a low price you can't go wrong
#
#
# Evidence for low price:
#
#    I have purchase multiple pairs (what a low price!)
#
#
# Evidence for low price:
#
#  I almost skipped this product due to the low price and what I assumed would be poor sound quality
#
#
# Evidence for low price:
#
#   I hope they will last, however I bought 2 pair so I have one as a back up since the price is low
#
#
# Evidence for lower quality:
#
#  If you look at these and you think they are to basic and that the price says something on lower quality, you'd be wrong in many a right
#
#
# Evidence for disappointing bass:
#
#   I read all of the glowing reviews for these and it really got my hopes up but even though these sound much better than the JVC Sport Clips, the bass is still disappointing
#
#
# Evidence for weak sound:
#
#    The sound is super weak though
#
#
# Evidence for bad sound:
#
#    The sound isn't bad either
#
#
# Evidence for poor sound:
#
#   After shopping everywhere on line and brick and mortar stores all I found were those hot uncomfortable ones with poor sound
#
#
# Evidence for bad sound:
#
#  The sound is not bad and they are very light, but the cord is so short that if you have your player in your pocket and are on the treadmill, the cord will get yanked out of the player
#
#
# Evidence for low price:
#
#    Love the low price and free shipping over $25!  Why pay $30 - $40 at a brick and mortar store for the same cable?Some reviewers had mentioned taking much time in receiving the cable
#
#
# Evidence for low price:
#
#  I found that it was a steal to buy this cable at such a low price
#
#
# Evidence for wrong wallet:
#
#  I am sorry to say I think I ordered the wrong wallet from my DVDs
#
#
# Evidence for difficult zipper:
#
#   My only complaint is that the zipper can be difficult to &quot;start&quot; since it rests along the spine
#
#
# Evidence for tricky zipper:
#
#   When fully opened the zipper can be a little tricky to close, other than that I like it
#
#
# Evidence for broke zipper:
#
#    My zipper never broke but if it had this CD/DVD holder would have been quite useless to me
#
#
# Evidence for broke zipper:
#
#    I bought this one because the old case I have ,even though is stronger than this one, the zipper broke few weeks later that I bought it
#
#
# Evidence for annoying zipper:
#
#   The zipper is a little annoying when trying to close because I've found it to be a two-hand operation, but besides that it's a good case
#
#
# Evidence for hard zipper:
#
#    The handle on the end is gone and the zipper is hard to close after being opened all the way due to an excess of nylon fabric
#
#
# Evidence for wrong case:
#
#    I thought I received the wrong case - it was a slightly different design - but the tag indicated that it was, in fact, the CDW-16
#
#
# Evidence for tough case:
#
#  This case is tough for the price
#
#
# Evidence for blurry exposure:
#
#  The more I use my Powershot G10 on tripods or try to do long exposures, the more I realize that when my finger presses down on the shutter, it slightly vibrates the camera and I get a slightly blurry exposure
#
#
# Evidence for low volume:
#
#   You need to have a headphone amplifier because the volume would be really low
#
#
# Evidence for annoying sound:
#
#  When there is nothing playing you can hear the ocean!  It's like the sound of a seashell, very annoying
#
#
# Evidence for Bad quality:
#
#  - Bad sound quality
#
#
# Evidence for low quality:
#
#  Sound quality is pretty low on these, and they feel a bit cheap
#
#
# Evidence for poor quality:
#
#    They are poor sound quality and generally I love Sony products
#
#
# Evidence for poor quality:
#
#   The quality of the sound is poor, they are made of cheap, cheap materials
#
#
# Evidence for bad quality:
#
#  I liked these headphones when I received them it was bad quality, I can only hear on one side and if i hold the plug the right direction!!! NOT HAPPY :-(They weren't the cheapest either
#
#
# Evidence for poor quality:
#
#  The headphones looks nice, but sound quality is poor
#
#
# Evidence for Terrible quality:
#
#   Terrible sound quality!!!!!! Find a better set to buy
#
#
# Evidence for poorest quality:
#
#   But the quality of the actual headphones is the poorest of its kind
#
#
# Evidence for hard plastic:
#
#   The only gripe we whould have is the hard plastic going over your head
#
#
# Evidence for hard plastic:
#
#  The quality is VERY, VERY fragile and hard-plastic; it is of utmost discomfort
#
#
# Evidence for poor battery life:
#
#    One final comment is about relatively poor battery life
#
#
# Evidence for crappy customer support:
#
#   The only constant is the crappy customer support
#
#
# Evidence for stupid button:
#
#   or if the DVD player is working properly with a stupid OK button on the button
#
#
# Evidence for tough button:
#
#    In this one, the onscreen button for menu is tough to hit with accuracy with big fingers
#
#
# Evidence for hard button:
#
#   The RF Extender also adds a slight delay to the equation because when you push a hard button or touch the screen, there's a nano second delay before you get the desired result
#
#
# Evidence for horrible interface:
#
#  My main problem with this remote is the horrible interface
#
#
# Evidence for awful Harmony:
#
#   The Harmony 1000 is definitely not as bad (my Harmony 720 was awful at this - and I had two!)
#
#
# Evidence for hard button Volume:
#
#   Some minor issues: The hard button Volume and Channel buttons are hard to see in the dark even with the backlighting of the button, I did get them confused a few times at first
#
#
# Evidence for hard button Volume:
#
#   Some minor issues: The hard button Volume and Channel buttons are hard to see in the dark even with the backlighting of the button, I did get them confused a few times at first
#
#
# Evidence for limited control:
#
#    Worse, it offers very limited control of devices--so you have to get your original device remotes out all the time to handle specialized functions
#
#
# Evidence for odd error:
#
#    But, it is functional and easy/logical to use (minus the odd grammatical error)
#
#
# Evidence for lowest price:
#
#    As my two favorite brick and mortar stores for AV acessories are Radio Shack and Best Buy, I went for the highest customer rated one at the lowest price
#
#
# Evidence for lower price:
#
#    As far as ranking the antennas for reception:1) Radio Shack's 15-1880  Best2) Terk HDTVi  Very good3) Philips SCA050  Very good4) Terk TV5  DecentThe Terk HDTV wins out because of the lower price, the fact that it is unamplified, had very good reception, and took up the least space
#
#
# Evidence for bad picture:
#
#    If you are getting a bad picture, an amplifier will not improve it, it will only increase the power of the bad signal resulting in a 'louder' bad signal
#
#
# Evidence for lower antenna gain:
#
#   The TERK with lower antenna gain will not be as sensitive to the direction pointing for reception as the Antenna Hub
#
#
# Evidence for wrong direction:
#
#  I moved and my patio is facing the wrong direction
#
#
# Evidence for inferior HD antenna:
#
#  Is an inferior HD antenna, and that is the main reason I bought it
#
#
# Evidence for difficult reception:
#
#    However, indoor reception of digital VHF stations is generally more difficult than for digital UHF - that's because of the laws of physics that require a larger antenna for lower frequencies, and is not the fault of the antenna
#
#
# Evidence for bad signal:
#
#    If you are getting a bad picture, an amplifier will not improve it, it will only increase the power of the bad signal resulting in a 'louder' bad signal
#
#
# Evidence for bad signal:
#
#    If you are getting a bad picture, an amplifier will not improve it, it will only increase the power of the bad signal resulting in a 'louder' bad signal
#
#
# Evidence for unstable base:
#
#  - The base of the antenna is very unstable
#
#
# Evidence for defective antenna:
#
#    Others who have had problems may have had a defective antenna, but perhaps needed to reboot their tuner/receiver
#
#
# Evidence for Bad Reception:
#
#  SUCKS!!! DO NOT BUY IT!!! HD? Why dun you get yourself a cable!!! Bad Reception
#
#
# Evidence for poor quality:
#
#   I live in urban area, /closer 3mi to broadcast antenna/ but quality is poor, always need move position when you want whole channel
#
#
# Evidence for weak NBC signal:
#
#    I was also able to get a weak NBC signal unlike any other antenna I had, but the signal just wasn't strong enough
#
#
# Evidence for limited range:
#
#    That said, I found the range very limited
#
#
# Evidence for poor range:
#
#    So, because of the problem with the firmware and the poor range I'm only giving the unit 3 stars
#
#
# Evidence for poor range:
#
#  11g system, which had such poor range that I couldn't go more than 15 feet without losing the signal
#
#
# Evidence for poor range:
#
#  Installation was quick but signal range is extemely poor
#
#
# Evidence for bad range:
#
#   Ihave never experienced some of the problems others complained about (reboots,bad range, etc
#
#
# Evidence for poor connection:
#
#    I also get a very poor connection to my linksys 802
#
#
# Evidence for lowest price:
#
#   I recommend getting it at the lowest price possible since they have discontinued manufacturing it
#
#
# Evidence for TERRIBLE support:
#
#  Again, great product, but TERRIBLE support and problem response
#
#
# Evidence for inadequate support:
#
#   And, the technical support, while courteous, was totally inadequate
#
#
# Evidence for defective battery:
#
#   2 due to hardware malfunction and one due to a defective battery which broke the battery cover and become swollen
#
#
# Evidence for bad battery:
#
#    This narrowed the problem down to either a bad battery or a bad charger
#
#
# Evidence for lower part:
#
#    Depending on the component and how the commands were stored in the remote, you can use either or both of the commands displayed in the lcd portion of the remote or the command buttons on the lower part of the remote
#
#
# Evidence for worst part:
#
#    The worst part about this situation is that this item was sold directly by Amazon and not by a one of their affiliate vendors
#
#
# Evidence for poor software:
#
#    I was almost concluding this is just one more nice hardware with a poor software and then I found out that the one the buttons (the right direction one) just doesn't work for any of my devices (TV, DVD and Xbox)
#
#
# Evidence for sluggish performance:
#
#  My remaining complaints are intermittent lockups of the remote itself (with new firmware promised 'soon'), and sluggish performance (key presses take a long while to transmit from the RF extender intermittently, as long as 5 seconds sometimes)
#
#
# Evidence for bad charger:
#
#    This narrowed the problem down to either a bad battery or a bad charger
#
#
# Evidence for bad charger:
#
#    This narrowed the problem down to either a bad battery or a bad charger
#
#
# Evidence for lousy documentation:
#
#   The documentation on customizing is lousy and needs to be written to show what this product really is capable of doing
#
#
# Evidence for poor documentation:
#
#    Although the documentation that came with the remote was poor, the Logitech discussion thread provided excellent advice
#
#
# Evidence for useless documentation:
#
#  There areas that could be improved:> The included documentation is almost useless
#
#
# Evidence for weak midrange:
#
#   The soundstage is great, bass has a nice full sound to it and there is decent treble, but the midrange is weak, grainy,and muddy
#
#
# Evidence for torn cord:
#
#  I recently purchased these, about 1 month ago, and the left speaker blew out all ready!! The cord has torn
#
#
# Evidence for worst part:
#
#  The worst part of these earbuds is that they won't stay in my ears
#
#
# Evidence for annoying noise:
#
#  As long as you can wear these so the cords do not rub against your clothes, they are great!Even sitting at a desk all day listing to music, the transfer of noise from rubbing against my shirt can be very annoying
#
#
# Evidence for annoying transfer:
#
#  As long as you can wear these so the cords do not rub against your clothes, they are great!Even sitting at a desk all day listing to music, the transfer of noise from rubbing against my shirt can be very annoying
#
#
# Evidence for weird plug:
#
#    The weird angled plug is because earlier versions fell apart after a few weeks
#
#
# Evidence for weak bass:
#
#    I noticed that they wouldn't stay in my ears very well and the bass was kinda weak
#
#
# Evidence for weak bass:
#
#    These buds have a better, cleaner, bass than the Senheiser 448's that I own (decent cans weak bass even after EQ adjust
#
#
# Evidence for low bass response:
#
#  I had done a lot of research and had bought another pair of highly rated earbuds, only to find low bass response
#
#
# Evidence for strange design:
#
#    It's a strange design and I'm not sure why they designed the plug with a 45-deg t-style plug I could see it getting damaged with the wrong jerking motion
#
#
# Evidence for low end bass:
#
#  They also have excellent low end bass, not boomy or bassy but deep amd large
#
#
# Evidence for odd shape:
#
#    This causes somewhat of an odd shape that allows for rubbing on your ear
#
#
# Evidence for poor quality:
#
#  I loved these, but now they are not working!  Bought them in Oct and now they are already broken!  One of the wires broke so you only get sound in one ear!  NOT GOOD, quality must be poor in how they build them
#
#
# Evidence for tough quality:
#
#    The build quality is "tough", these buds are metal, and they are substantial, cram them in your ears as much as you wish, there not going to break
#
#
# Evidence for lower quality:
#
#    In addition to the slightly lower sound quality, I have to have my Clipper at a notch higher volume setting to get a comparable sound level
#
#
# Evidence for low quality:
#
#  I was so happy in the day I recieved the headset but so dissapointed when pluged it and heared the sound it is abnormal very low quality even I thought something wrong with my handset for that I changed it with another one but the sound quality was less than low(bad) even it is harmful to the ears,I couldn't hear the bass and the strange thing the sound looks like distorted and oes contains some disturbing eco,but still the shape of the headphone is very good but never can use it for hearing songs,if you gonna buy one of these you can use it just to say I have a headphone never to hear music with
#
#
# Evidence for low price:
#
#  I ultimately decided on these headphones because of the Sony brand, the low price in relation to retail, and the other great reviews they received in comparison with others in their class
#
#
# Evidence for unwanted noise:
#
#   and does a stand up job of filtering out unwanted noise especially when I am trying to sleep
#
#
# Evidence for unwanted noise:
#
#    Long story short, they work very well for blocking out unwanted noise
#
#
# Evidence for annoying noise:
#
#    Unfortunately, IMHO, they were only OK -- uncomfortable on the ears, didn't cancel much ambient noise, and in noise-cancelling mode just created an annoying white noise
#
#
# Evidence for hard plastic:
#
#    They are not uncomfortable, but they are not comfortable either-the headphones themselves are hard plastic covered with thin, scratchy covers
#
#
# Evidence for bothered sound:
#
#   The hissing sound bothered me at first but when you actually listen to music you don't notice it at all
#
#
# Evidence for distorted sound:
#
#  I used these on three air trips until on the 4th one they suddenly started delivering low-volume, distorted sound
#
#
# Evidence for poor quality:
#
#   I'm not sure if this was due to an accident on my part or poor quality
#
#
# Evidence for miserable quality:
#
#   However, the sound quality is miserable as well
#
#
# Evidence for lower volume:
#
#    Isn't the whole point of noise canceling headphones to listen to your music at a lower volume without having to blow your ear drums out from cranking up the music to overcome ambient noise?  It even advertises this fact on the box
#
#
# Evidence for low level:
#
#   They do work VERY well on low level, low frequency noises
#
#
# Evidence for low level:
#
#    The "noise reduction" feature is silly, too, apparently it's just the headphones playing a low level of white noise
#
#
# Evidence for noisy flight:
#
#  Though I'm not Sony's fan, I was pleased with sound quality and quieting I enjoyed in noisy flight
